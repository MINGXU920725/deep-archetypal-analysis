# %% [markdown]
# # VAE-aa
# https://arxiv.org/abs/2002.00815
#
# Learning Extremal Representations with Deep Archetypal Analysis

# %% [markdown]
# The following plots aggregate the GPU results saved from multiple K and
# seed configurations to determine the optimal K.
#
# calculate the NMI, consistency, and loss of the identified AA archetypes to determine the optimal number of K.

# %%
import matplotlib.pyplot as plt

K = np.array(K_LIST)

nmi_mean = np.array([results[k]["nmi_mean"] for k in K_LIST])
nmi_std  = np.array([results[k]["nmi_std"] for k in K_LIST])

cons_mean = np.array([results[k]["cons_mean"] for k in K_LIST])
cons_std  = np.array([results[k]["cons_std"] for k in K_LIST])

loss_mean = np.array([results[k]["loss_mean"] for k in K_LIST])

# --- Create a 2-row figure: first row (NMI, Consistency), second row (Loss)
fig, axes = plt.subplots(2, 2, figsize=(14, 8))
ax1, ax2 = axes[0]
ax3 = axes[1, 0]

# Hide the empty bottom-right subplot
axes[1, 1].axis("off")

# ----------------------  1: NMI ----------------------
ax1.plot(K, nmi_mean, marker='o', color='blue', label="NMI mean")
ax1.set_xlabel("K")
ax1.set_ylabel("NMI mean", color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_title("NMI vs K")
ax1.grid(True)

ax1r = ax1.twinx()
ax1r.plot(K, nmi_std, marker='s', color='red', label="NMI std")
ax1r.set_ylabel("NMI std", color='red')
ax1r.tick_params(axis='y', labelcolor='red')

# ----------------------  2: Consistency ----------------------
ax2.plot(K, cons_mean, marker='o', color='blue', label="Consistency mean")
ax2.set_xlabel("K")
ax2.set_ylabel("Consistency mean", color='blue')
ax2.tick_params(axis='y', labelcolor='blue')
ax2.set_title("Consistency vs K")
ax2.grid(True)

ax2r = ax2.twinx()
ax2r.plot(K, cons_std, marker='s', color='red', label="Consistency std")
ax2r.set_ylabel("Consistency std", color='red')
ax2r.tick_params(axis='y', labelcolor='red')

# ----------------------  3: Loss (Second row) ----------------------
ax3.plot(K, loss_mean, marker='o', color='green', label="Loss mean")
ax3.set_xlabel("K")
ax3.set_ylabel("Loss mean", color='green')
ax3.tick_params(axis='y', labelcolor='green')
ax3.set_title("Final Loss vs K")
ax3.grid(True)

plt.tight_layout()
plt.show()

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Subset
from torchvision import datasets, transforms
import random, numpy as np, os, json, pickle
from sklearn.cluster import KMeans

# -----------------------------
# -----------------------------
config = {
    "dataset": "mnist",
    "batch_size": 500,
    "max_epochs": 50,
    "latent_dim": 32,
    "lr": 0.005,
    "train_subset_size": 20000,
    "warmup_epochs": 5,
    "semantic_epochs": 10,
    "nu_x_tilde": 200,
    "gamma": 60.0,
    "beta": 0.01,
    "alpha": 0.1,
    "cos_sim_weight": 1.0,
    "num_classes": 10,
    "num_archetypes_per_class": 5,
    "total_archetypes": 50,
    "SEED": 42,
    "exp_dir": "./results/mnist_notebook_seed42_aa5"
}

os.makedirs(config["exp_dir"], exist_ok=True)


# -----------------------------
def set_seed(s):
    random.seed(s)
    np.random.seed(s)
    torch.manual_seed(s)
    torch.cuda.manual_seed_all(s)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(config["SEED"])
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"[Init] Using device: {device}")


# -----------------------------
transform = transforms.Compose([transforms.ToTensor()])
if config["dataset"] == "mnist":
    full_train_set = datasets.MNIST("./data", train=True, download=True, transform=transform)
    test_set = datasets.MNIST("./data", train=False, download=True, transform=transform)
else:
    raise ValueError("Only MNIST supported for this notebook version")

train_loader_full = DataLoader(full_train_set, batch_size=config["batch_size"], shuffle=True)
test_loader = DataLoader(test_set, batch_size=config["batch_size"], shuffle=False)

def prepare_class_full_data(dataset, device):
    class_full_imgs = {}
    for img, label in dataset:
        label = int(label)
        if label not in class_full_imgs:
            class_full_imgs[label] = []
        class_full_imgs[label].append(img.unsqueeze(0))
    for label in class_full_imgs:
        class_full_imgs[label] = torch.cat(class_full_imgs[label]).to(device)
    return class_full_imgs

class_full_imgs = prepare_class_full_data(full_train_set, device)

# -----------------------------
class VAEWithAA(nn.Module):
    def __init__(self, latent_dim=32, img_channels=1, img_size=28, num_classes=10):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(1, 32, 3, stride=2, padding=1), nn.ReLU(),
            nn.BatchNorm2d(32),
            nn.Conv2d(32, 64, 3, stride=2, padding=1), nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.Flatten(),
            nn.Linear(7 * 7 * 64, 512), nn.ReLU(),
            nn.Linear(512, latent_dim * 2)
        )
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 512), nn.ReLU(),
            nn.Linear(512, 7 * 7 * 64),
            nn.Unflatten(1, (64, 7, 7)),
            nn.ConvTranspose2d(64, 32, 4, 2, 1), nn.ReLU(),
            nn.ConvTranspose2d(32, 1, 4, 2, 1), nn.Sigmoid()
        )
        self.classifier = nn.Sequential(
            nn.Linear(latent_dim, 128), nn.ReLU(), nn.Linear(128, num_classes)
        )
        self.arch_logits = nn.ParameterDict()
        self.class_full_mu = {}
        self.fc_sample_to_aa = nn.Linear(latent_dim, config["total_archetypes"])

    def encode(self, x):
        h = self.encoder(x)
        mu, logvar = torch.chunk(h, 2, dim=1)
        mu = mu / (mu.norm(dim=1, keepdim=True) + 1e-8)
        return mu, logvar

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def decode(self, z):
        return self.decoder(z)

    def init_class_archetypes(self, class_full_imgs, device):
        print("[Init] Initializing class-wise archetypes (multi-seed + fallback)...")
        for label, imgs in class_full_imgs.items():
            mu, _ = self.encode(imgs)
            self.class_full_mu[label] = mu.detach()
            mu_np = mu.detach().cpu().numpy()
            target_num = config["num_archetypes_per_class"]

            centers_np = None
            for seed_offset in range(5):
                try_seed = config["SEED"] + seed_offset
                km = KMeans(n_clusters=target_num, random_state=try_seed, n_init=10, max_iter=300).fit(mu_np)
                centers_np = km.cluster_centers_
                break

            centers = torch.tensor(centers_np, device=device, dtype=mu.dtype)
            dists = torch.cdist(centers, mu)
            idx = dists.topk(k=20, largest=False).indices
            logits = torch.zeros(target_num, mu.size(0), device=device)
            for i in range(target_num):
                logits[i, idx[i]] = 5.0
            self.arch_logits[str(label)] = nn.Parameter(logits, requires_grad=True)
        print("[Init] Archetypes initialized.")

    def get_all_archetypes(self):
        all_arch = []
        for label in sorted(self.arch_logits.keys()):
            W = F.softmax(self.arch_logits[label], dim=1)
            X_mu_full = self.class_full_mu[int(label)]
            all_arch.append(W @ X_mu_full)
        return torch.cat(all_arch, dim=0)

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        sample_to_aa_weights = F.softmax(self.fc_sample_to_aa(mu), dim=1)
        x_hat = self.decode(z)
        return x_hat, z, mu, logvar, sample_to_aa_weights


# -----------------------------
def kl_loss(mu, logvar):
    return -0.5 * torch.mean(1 + logvar - mu.pow(2) - logvar.exp())

def recon_loss(x_hat, x):
    return F.mse_loss(x_hat, x, reduction='mean')

def estimate_mutual_info_ty(mu, classifier, num_classes=10):
    logits = classifier(mu)
    probs = F.softmax(logits, dim=1)
    entropy_cond = -torch.sum(probs * torch.log(probs + 1e-8), dim=1).mean()
    return -entropy_cond

def cos_similarity_loss(mu_batch, all_archetypes, weights_batch):
    recon_sample = torch.matmul(weights_batch, all_archetypes)
    cos_sim = F.cosine_similarity(recon_sample, mu_batch, dim=1).mean()
    return (1 - cos_sim)

def total_aa_loss(model, mu):
    all_archetypes = model.get_all_archetypes()
    weights_batch = F.softmax(model.fc_sample_to_aa(mu), dim=1)
    loss_sample = F.mse_loss(torch.matmul(weights_batch, all_archetypes), mu)
    loss_cos = cos_similarity_loss(mu, all_archetypes, weights_batch)
    total_loss = loss_sample + config["cos_sim_weight"] * loss_cos
    return total_loss, loss_sample.item(), loss_cos.item()


# -----------------------------
model = VAEWithAA(latent_dim=config["latent_dim"]).to(device)
optimizer = torch.optim.Adam([{"params": model.parameters(), "lr": config["lr"]}])
epoch_losses = []

print(f"[Training Start] {config['max_epochs']} epochs total")
print(f"Warmup: first {config['warmup_epochs']} epochs | Semantic: {config['warmup_epochs']+1}–{config['semantic_epochs']} | AA starts from {config['semantic_epochs']+1}")
print(f"[Config] batch_size={config['batch_size']} | lr={config['lr']} | gamma={config['gamma']} | cos_sim_weight={config['cos_sim_weight']}\n")

for epoch in range(config["max_epochs"]):
    print(f"===================== Epoch {epoch+1}/{config['max_epochs']} =====================")
    if epoch < config["warmup_epochs"]:
        print("Mode: Warmup (KL + Reconstruction)")
    elif epoch < config["semantic_epochs"]:
        print("Mode: Semantic (KL + Recon + weak MI)")
    else:
        print("Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)")

    rand_idx = random.sample(range(len(full_train_set)), config["train_subset_size"])
    train_subset = Subset(full_train_set, rand_idx)
    train_loader = DataLoader(train_subset, batch_size=config["batch_size"], shuffle=True)
    
    if epoch == config["semantic_epochs"]:
        model.init_class_archetypes(class_full_imgs, device)
        for p in model.arch_logits.parameters():
            p.requires_grad = True
        optimizer.add_param_group({"params": model.arch_logits.parameters(), "lr": 1e-2})

    total_loss_sum, total_samples = 0, 0
    model.train()
    for batch_idx, (x, y) in enumerate(train_loader):
        x, y = x.to(device), y.to(device)
        x_hat, z, mu, logvar, sample_to_aa = model(x)

        I_tx = kl_loss(mu, logvar)
        recon = recon_loss(x_hat, x)
        I_ty_raw = estimate_mutual_info_ty(mu, model.classifier, config["num_classes"])
        I_ty_display = -I_ty_raw

        if epoch >= config["semantic_epochs"]:
            L_at, avg_Ls, avg_La = total_aa_loss(model, mu)
        else:
            L_at, avg_Ls, avg_La = torch.tensor(0.0).to(device), 0.0, 0.0

        if epoch < config["warmup_epochs"]:
            total_loss = I_tx + config["nu_x_tilde"] * recon
        elif epoch < config["semantic_epochs"]:
            total_loss = I_tx - (config["beta"] * 0.5) * I_ty_raw + config["nu_x_tilde"] * recon
        else:
            total_loss = I_tx - config["beta"] * I_ty_raw + config["nu_x_tilde"] * recon + config["gamma"] * L_at

        optimizer.zero_grad()
        total_loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 5.0)
        optimizer.step()

        bs = x.size(0)
        total_loss_sum += total_loss.item() * bs
        total_samples += bs

        if (batch_idx + 1) % 10 == 0:
            print(f"[Train] Batch {batch_idx+1:03d} | I(t;x): {I_tx.item():.4f} | I(t;y): {I_ty_display.item():.4f} | Recon: {recon.item():.4f} | Total: {total_loss.item():.4f}")
            if epoch >= config["semantic_epochs"]:
                print(f"   ↳ AA sample loss: {avg_Ls:.6f} | AA cos loss: {avg_La:.6f}")

    avg_loss = total_loss_sum / total_samples
    epoch_losses.append(avg_loss)
    print(f"\n[Summary] Epoch {epoch+1} Train Total Loss: {avg_loss:.4f}")
    print("=======================================================================\n")

# -----------------------------
loss_path = os.path.join(config["exp_dir"], "epoch_total_losses.pkl")
with open(loss_path, "wb") as f:
    pickle.dump(epoch_losses, f)
print(f"[Save] Epoch losses saved to: {loss_path}")

if hasattr(model, "get_all_archetypes"):
    all_arch = model.get_all_archetypes().cpu().detach().numpy()
    aa_path = os.path.join(config["exp_dir"], "final_archetypes.npy")
    np.save(aa_path, all_arch)
    decoded = model.decode(torch.tensor(all_arch, device=device)).cpu().detach().numpy()
    np.save(os.path.join(config["exp_dir"], "final_archetypes_decoded.npy"), decoded)
    print(f"[Save] Archetypes & decoded saved in: {config['exp_dir']}")

torch.save(model.state_dict(), os.path.join(config["exp_dir"], "model_final.pth"))
print(f"[Save] Final model saved to: {config['exp_dir']}")

torch.save(model, os.path.join(config["exp_dir"], "model_full.pth"))
print(f"[Save] Full model (with archetypes & AA mapping) saved to: {config['exp_dir']}")


print("\n[PostProcess] Saving full latent reconstruction results (correct AA reconstruction) ...")

full_loader = DataLoader(full_train_set, batch_size=config["batch_size"], shuffle=False)

model.eval()
all_mu, all_mu_aa, all_decoded_mu, all_decoded_mu_aa, all_mse = [], [], [], [], []

with torch.no_grad():
    all_archetypes = model.get_all_archetypes().to(device)

    for x, _ in full_loader:
        x = x.to(device)
        mu, _ = model.encode(x)

        weights = F.softmax(model.fc_sample_to_aa(mu), dim=1)
        mu_aa = weights @ all_archetypes

        decoded_mu = model.decode(mu)
        decoded_mu_aa = model.decode(mu_aa)

        mse = F.mse_loss(decoded_mu_aa, x, reduction="none").mean(dim=[1, 2, 3])

        all_mu.append(mu.cpu())
        all_mu_aa.append(mu_aa.cpu())
        all_decoded_mu.append(decoded_mu.cpu())
        all_decoded_mu_aa.append(decoded_mu_aa.cpu())
        all_mse.append(mse.cpu())

all_mu = torch.cat(all_mu)
all_mu_aa = torch.cat(all_mu_aa)
all_decoded_mu = torch.cat(all_decoded_mu)
all_decoded_mu_aa = torch.cat(all_decoded_mu_aa)
all_mse = torch.cat(all_mse)

np.save(os.path.join(config["exp_dir"], "latent_mu.npy"), all_mu.numpy())
np.save(os.path.join(config["exp_dir"], "latent_mu_AA.npy"), all_mu_aa.numpy())
np.save(os.path.join(config["exp_dir"], "decoded_mu.npy"), all_decoded_mu.numpy())
np.save(os.path.join(config["exp_dir"], "decoded_mu_AA.npy"), all_decoded_mu_aa.numpy())
np.save(os.path.join(config["exp_dir"], "reconstruction_mse.npy"), all_mse.numpy())

mean_mse = all_mse.mean().item()
with open(os.path.join(config["exp_dir"], "reconstruction_mse_mean.txt"), "w") as f:
    f.write(f"Average MSE (AA reconstruction): {mean_mse:.6f}\n")

print(f"[Done] AA reconstruction results saved to: {config['exp_dir']}")
print(f"Average AA reconstruction MSE = {mean_mse:.6f}")
# Out:
# [Init] Using device: cpu
# [Training Start] 50 epochs total
# Warmup: first 5 epochs | Semantic: 6–10 | AA starts from 11
# [Config] batch_size=500 | lr=0.005 | gamma=60.0 | cos_sim_weight=1.0
#
# ===================== Epoch 1/50 =====================
# Mode: Warmup (KL + Reconstruction)
# [Train] Batch 010 | I(t;x): 0.2794 | I(t;y): 2.2992 | Recon: 0.0670 | Total: 13.6785
# [Train] Batch 020 | I(t;x): 0.1455 | I(t;y): 2.2998 | Recon: 0.0629 | Total: 12.7291
# [Train] Batch 030 | I(t;x): 0.2595 | I(t;y): 2.2997 | Recon: 0.0600 | Total: 12.2604
# [Train] Batch 040 | I(t;x): 0.4680 | I(t;y): 2.3000 | Recon: 0.0568 | Total: 11.8362
#
# [Summary] Epoch 1 Train Total Loss: 15.3167
# =======================================================================
#
# ===================== Epoch 2/50 =====================
# Mode: Warmup (KL + Reconstruction)
# [Train] Batch 010 | I(t;x): 0.6609 | I(t;y): 2.3000 | Recon: 0.0518 | Total: 11.0289
# [Train] Batch 020 | I(t;x): 0.7541 | I(t;y): 2.3002 | Recon: 0.0497 | Total: 10.6943
# [Train] Batch 030 | I(t;x): 0.8611 | I(t;y): 2.3003 | Recon: 0.0447 | Total: 9.8108
# [Train] Batch 040 | I(t;x): 0.9306 | I(t;y): 2.3004 | Recon: 0.0411 | Total: 9.1410
#
# [Summary] Epoch 2 Train Total Loss: 10.4522
# =======================================================================
#
# ===================== Epoch 3/50 =====================
# Mode: Warmup (KL + Reconstruction)
# [Train] Batch 010 | I(t;x): 1.0976 | I(t;y): 2.3005 | Recon: 0.0382 | Total: 8.7368
# [Train] Batch 020 | I(t;x): 1.0596 | I(t;y): 2.3001 | Recon: 0.0360 | Total: 8.2517
# [Train] Batch 030 | I(t;x): 0.9938 | I(t;y): 2.3004 | Recon: 0.0341 | Total: 7.8207
# [Train] Batch 040 | I(t;x): 0.9674 | I(t;y): 2.3004 | Recon: 0.0335 | Total: 7.6673
#
# [Summary] Epoch 3 Train Total Loss: 8.1826
# =======================================================================
#
# ===================== Epoch 4/50 =====================
# Mode: Warmup (KL + Reconstruction)
# [Train] Batch 010 | I(t;x): 0.9443 | I(t;y): 2.3004 | Recon: 0.0302 | Total: 6.9849
# [Train] Batch 020 | I(t;x): 0.9518 | I(t;y): 2.3003 | Recon: 0.0308 | Total: 7.1046
# [Train] Batch 030 | I(t;x): 0.9742 | I(t;y): 2.3004 | Recon: 0.0304 | Total: 7.0516
# [Train] Batch 040 | I(t;x): 0.9538 | I(t;y): 2.3003 | Recon: 0.0298 | Total: 6.9198
#
# [Summary] Epoch 4 Train Total Loss: 7.0964
# =======================================================================
#
# ===================== Epoch 5/50 =====================
# Mode: Warmup (KL + Reconstruction)
# [Train] Batch 010 | I(t;x): 0.9895 | I(t;y): 2.3004 | Recon: 0.0297 | Total: 6.9375
# [Train] Batch 020 | I(t;x): 0.9840 | I(t;y): 2.3006 | Recon: 0.0270 | Total: 6.3839
# [Train] Batch 030 | I(t;x): 0.9726 | I(t;y): 2.3004 | Recon: 0.0256 | Total: 6.1018
# [Train] Batch 040 | I(t;x): 0.9551 | I(t;y): 2.3007 | Recon: 0.0250 | Total: 5.9643
#
# [Summary] Epoch 5 Train Total Loss: 6.3857
# =======================================================================
#
# ===================== Epoch 6/50 =====================
# Mode: Semantic (KL + Recon + weak MI)
# [Train] Batch 010 | I(t;x): 0.9271 | I(t;y): 2.1519 | Recon: 0.0251 | Total: 5.9502
# [Train] Batch 020 | I(t;x): 0.9664 | I(t;y): 1.6006 | Recon: 0.0233 | Total: 5.6286
# [Train] Batch 030 | I(t;x): 0.9645 | I(t;y): 1.2085 | Recon: 0.0235 | Total: 5.6673
# [Train] Batch 040 | I(t;x): 0.9200 | I(t;y): 0.6019 | Recon: 0.0233 | Total: 5.5871
#
# [Summary] Epoch 6 Train Total Loss: 5.7431
# =======================================================================
#
# ===================== Epoch 7/50 =====================
# Mode: Semantic (KL + Recon + weak MI)
# [Train] Batch 010 | I(t;x): 0.9399 | I(t;y): 0.0666 | Recon: 0.0231 | Total: 5.5646
# [Train] Batch 020 | I(t;x): 0.9607 | I(t;y): 0.0046 | Recon: 0.0225 | Total: 5.4676
# [Train] Batch 030 | I(t;x): 0.9179 | I(t;y): 0.0012 | Recon: 0.0215 | Total: 5.2204
# [Train] Batch 040 | I(t;x): 0.9302 | I(t;y): 0.0005 | Recon: 0.0223 | Total: 5.3993
#
# [Summary] Epoch 7 Train Total Loss: 5.3978
# =======================================================================
#
# ===================== Epoch 8/50 =====================
# Mode: Semantic (KL + Recon + weak MI)
# [Train] Batch 010 | I(t;x): 0.9187 | I(t;y): 0.0006 | Recon: 0.0210 | Total: 5.1169
# [Train] Batch 020 | I(t;x): 0.9328 | I(t;y): 0.0004 | Recon: 0.0206 | Total: 5.0561
# [Train] Batch 030 | I(t;x): 0.9524 | I(t;y): 0.0004 | Recon: 0.0205 | Total: 5.0563
# [Train] Batch 040 | I(t;x): 0.9485 | I(t;y): 0.0003 | Recon: 0.0212 | Total: 5.1850
#
# [Summary] Epoch 8 Train Total Loss: 5.0697
# =======================================================================
#
# ===================== Epoch 9/50 =====================
# Mode: Semantic (KL + Recon + weak MI)
# [Train] Batch 010 | I(t;x): 0.9460 | I(t;y): 0.0003 | Recon: 0.0193 | Total: 4.8040
# [Train] Batch 020 | I(t;x): 0.9721 | I(t;y): 0.0004 | Recon: 0.0203 | Total: 5.0282
# [Train] Batch 030 | I(t;x): 0.9267 | I(t;y): 0.0003 | Recon: 0.0194 | Total: 4.7977
# [Train] Batch 040 | I(t;x): 0.9636 | I(t;y): 0.0003 | Recon: 0.0198 | Total: 4.9282
#
# [Summary] Epoch 9 Train Total Loss: 4.8878
# =======================================================================
#
# ===================== Epoch 10/50 =====================
# Mode: Semantic (KL + Recon + weak MI)
# [Train] Batch 010 | I(t;x): 0.9551 | I(t;y): 0.0003 | Recon: 0.0200 | Total: 4.9562
# [Train] Batch 020 | I(t;x): 0.9347 | I(t;y): 0.0002 | Recon: 0.0191 | Total: 4.7569
# [Train] Batch 030 | I(t;x): 0.8998 | I(t;y): 0.0003 | Recon: 0.0189 | Total: 4.6794
# [Train] Batch 040 | I(t;x): 0.9429 | I(t;y): 0.0003 | Recon: 0.0190 | Total: 4.7461
#
# [Summary] Epoch 10 Train Total Loss: 4.7423
# =======================================================================
#
# ===================== Epoch 11/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Init] Initializing class-wise archetypes (multi-seed + fallback)...
# [Init] Archetypes initialized.
# [Train] Batch 010 | I(t;x): 1.0327 | I(t;y): 0.0000 | Recon: 0.0493 | Total: 15.2535
#    ↳ AA sample loss: 0.024674 | AA cos loss: 0.047984
# [Train] Batch 020 | I(t;x): 1.5741 | I(t;y): 0.0000 | Recon: 0.0401 | Total: 11.6843
#    ↳ AA sample loss: 0.025002 | AA cos loss: 0.009876
# [Train] Batch 030 | I(t;x): 1.4666 | I(t;y): 0.0000 | Recon: 0.0329 | Total: 10.2393
#    ↳ AA sample loss: 0.025171 | AA cos loss: 0.011482
# [Train] Batch 040 | I(t;x): 1.5034 | I(t;y): 0.0000 | Recon: 0.0285 | Total: 9.3909
#    ↳ AA sample loss: 0.025338 | AA cos loss: 0.011116
#
# [Summary] Epoch 11 Train Total Loss: 16.1077
# =======================================================================
#
# ===================== Epoch 12/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.4855 | I(t;y): 0.0000 | Recon: 0.0264 | Total: 8.8287
#    ↳ AA sample loss: 0.025483 | AA cos loss: 0.008875
# [Train] Batch 020 | I(t;x): 1.4309 | I(t;y): 0.0000 | Recon: 0.0264 | Total: 8.7343
#    ↳ AA sample loss: 0.025639 | AA cos loss: 0.007989
# [Train] Batch 030 | I(t;x): 1.4121 | I(t;y): 0.0000 | Recon: 0.0257 | Total: 8.5650
#    ↳ AA sample loss: 0.025792 | AA cos loss: 0.007755
# [Train] Batch 040 | I(t;x): 1.3759 | I(t;y): 0.0000 | Recon: 0.0237 | Total: 8.0733
#    ↳ AA sample loss: 0.025900 | AA cos loss: 0.006596
#
# [Summary] Epoch 12 Train Total Loss: 8.6778
# =======================================================================
#
# ===================== Epoch 13/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.3544 | I(t;y): 0.0000 | Recon: 0.0224 | Total: 7.7755
#    ↳ AA sample loss: 0.025961 | AA cos loss: 0.006264
# [Train] Batch 020 | I(t;x): 1.3473 | I(t;y): 0.0000 | Recon: 0.0228 | Total: 7.8033
#    ↳ AA sample loss: 0.026026 | AA cos loss: 0.005648
# [Train] Batch 030 | I(t;x): 1.3304 | I(t;y): 0.0000 | Recon: 0.0221 | Total: 7.6404
#    ↳ AA sample loss: 0.026084 | AA cos loss: 0.005321
# [Train] Batch 040 | I(t;x): 1.3102 | I(t;y): 0.0000 | Recon: 0.0219 | Total: 7.5453
#    ↳ AA sample loss: 0.026061 | AA cos loss: 0.004902
#
# [Summary] Epoch 13 Train Total Loss: 7.7096
# =======================================================================
#
# ===================== Epoch 14/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.2718 | I(t;y): 0.0000 | Recon: 0.0209 | Total: 7.2973
#    ↳ AA sample loss: 0.025995 | AA cos loss: 0.004643
# [Train] Batch 020 | I(t;x): 1.2715 | I(t;y): 0.0000 | Recon: 0.0203 | Total: 7.1306
#    ↳ AA sample loss: 0.025978 | AA cos loss: 0.004151
# [Train] Batch 030 | I(t;x): 1.2318 | I(t;y): 0.0000 | Recon: 0.0208 | Total: 7.1844
#    ↳ AA sample loss: 0.025919 | AA cos loss: 0.003841
# [Train] Batch 040 | I(t;x): 1.2294 | I(t;y): 0.0000 | Recon: 0.0194 | Total: 6.8773
#    ↳ AA sample loss: 0.025905 | AA cos loss: 0.003552
#
# [Summary] Epoch 14 Train Total Loss: 7.2116
# =======================================================================
#
# ===================== Epoch 15/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.2062 | I(t;y): 0.0000 | Recon: 0.0205 | Total: 7.0787
#    ↳ AA sample loss: 0.025828 | AA cos loss: 0.003557
# [Train] Batch 020 | I(t;x): 1.2286 | I(t;y): 0.0000 | Recon: 0.0204 | Total: 7.0611
#    ↳ AA sample loss: 0.025759 | AA cos loss: 0.003580
# [Train] Batch 030 | I(t;x): 1.2342 | I(t;y): 0.0000 | Recon: 0.0191 | Total: 6.7732
#    ↳ AA sample loss: 0.025689 | AA cos loss: 0.003123
# [Train] Batch 040 | I(t;x): 1.2214 | I(t;y): 0.0000 | Recon: 0.0195 | Total: 6.8470
#    ↳ AA sample loss: 0.025649 | AA cos loss: 0.003074
#
# [Summary] Epoch 15 Train Total Loss: 6.9663
# =======================================================================
#
# ===================== Epoch 16/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.1752 | I(t;y): 0.0000 | Recon: 0.0192 | Total: 6.7272
#    ↳ AA sample loss: 0.025499 | AA cos loss: 0.003049
# [Train] Batch 020 | I(t;x): 1.1558 | I(t;y): 0.0000 | Recon: 0.0185 | Total: 6.5620
#    ↳ AA sample loss: 0.025421 | AA cos loss: 0.002988
# [Train] Batch 030 | I(t;x): 1.1791 | I(t;y): 0.0000 | Recon: 0.0188 | Total: 6.6372
#    ↳ AA sample loss: 0.025349 | AA cos loss: 0.002888
# [Train] Batch 040 | I(t;x): 1.2235 | I(t;y): 0.0000 | Recon: 0.0192 | Total: 6.7534
#    ↳ AA sample loss: 0.025309 | AA cos loss: 0.002890
#
# [Summary] Epoch 16 Train Total Loss: 6.7131
# =======================================================================
#
# ===================== Epoch 17/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.1948 | I(t;y): 0.0000 | Recon: 0.0186 | Total: 6.5814
#    ↳ AA sample loss: 0.025219 | AA cos loss: 0.002708
# [Train] Batch 020 | I(t;x): 1.1626 | I(t;y): 0.0000 | Recon: 0.0182 | Total: 6.4652
#    ↳ AA sample loss: 0.025163 | AA cos loss: 0.002497
# [Train] Batch 030 | I(t;x): 1.1454 | I(t;y): 0.0000 | Recon: 0.0185 | Total: 6.4896
#    ↳ AA sample loss: 0.025021 | AA cos loss: 0.002438
# [Train] Batch 040 | I(t;x): 1.1452 | I(t;y): 0.0000 | Recon: 0.0186 | Total: 6.5004
#    ↳ AA sample loss: 0.024952 | AA cos loss: 0.002416
#
# [Summary] Epoch 17 Train Total Loss: 6.5444
# =======================================================================
#
# ===================== Epoch 18/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.1662 | I(t;y): 0.0000 | Recon: 0.0178 | Total: 6.3608
#    ↳ AA sample loss: 0.024826 | AA cos loss: 0.002479
# [Train] Batch 020 | I(t;x): 1.1859 | I(t;y): 0.0000 | Recon: 0.0182 | Total: 6.4747
#    ↳ AA sample loss: 0.024753 | AA cos loss: 0.002613
# [Train] Batch 030 | I(t;x): 1.1293 | I(t;y): 0.0000 | Recon: 0.0174 | Total: 6.2196
#    ↳ AA sample loss: 0.024643 | AA cos loss: 0.002348
# [Train] Batch 040 | I(t;x): 1.0943 | I(t;y): 0.0000 | Recon: 0.0183 | Total: 6.3750
#    ↳ AA sample loss: 0.024632 | AA cos loss: 0.002349
#
# [Summary] Epoch 18 Train Total Loss: 6.4350
# =======================================================================
#
# ===================== Epoch 19/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.1240 | I(t;y): 0.0000 | Recon: 0.0184 | Total: 6.4109
#    ↳ AA sample loss: 0.024488 | AA cos loss: 0.002283
# [Train] Batch 020 | I(t;x): 1.1317 | I(t;y): 0.0000 | Recon: 0.0185 | Total: 6.4384
#    ↳ AA sample loss: 0.024420 | AA cos loss: 0.002382
# [Train] Batch 030 | I(t;x): 1.1307 | I(t;y): 0.0000 | Recon: 0.0171 | Total: 6.1451
#    ↳ AA sample loss: 0.024299 | AA cos loss: 0.002397
# [Train] Batch 040 | I(t;x): 1.1343 | I(t;y): 0.0000 | Recon: 0.0173 | Total: 6.1826
#    ↳ AA sample loss: 0.024122 | AA cos loss: 0.002514
#
# [Summary] Epoch 19 Train Total Loss: 6.3327
# =======================================================================
#
# ===================== Epoch 20/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.1310 | I(t;y): 0.0000 | Recon: 0.0181 | Total: 6.3248
#    ↳ AA sample loss: 0.023994 | AA cos loss: 0.002402
# [Train] Batch 020 | I(t;x): 1.1250 | I(t;y): 0.0000 | Recon: 0.0177 | Total: 6.2822
#    ↳ AA sample loss: 0.023956 | AA cos loss: 0.002859
# [Train] Batch 030 | I(t;x): 1.1274 | I(t;y): 0.0000 | Recon: 0.0176 | Total: 6.1972
#    ↳ AA sample loss: 0.023775 | AA cos loss: 0.002159
# [Train] Batch 040 | I(t;x): 1.1055 | I(t;y): 0.0000 | Recon: 0.0176 | Total: 6.1811
#    ↳ AA sample loss: 0.023580 | AA cos loss: 0.002356
#
# [Summary] Epoch 20 Train Total Loss: 6.2503
# =======================================================================
#
# ===================== Epoch 21/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.1135 | I(t;y): 0.0000 | Recon: 0.0176 | Total: 6.1919
#    ↳ AA sample loss: 0.023492 | AA cos loss: 0.002375
# [Train] Batch 020 | I(t;x): 1.1504 | I(t;y): 0.0000 | Recon: 0.0172 | Total: 6.1291
#    ↳ AA sample loss: 0.023350 | AA cos loss: 0.002262
# [Train] Batch 030 | I(t;x): 1.1138 | I(t;y): 0.0000 | Recon: 0.0178 | Total: 6.2054
#    ↳ AA sample loss: 0.023256 | AA cos loss: 0.002292
# [Train] Batch 040 | I(t;x): 1.1113 | I(t;y): 0.0000 | Recon: 0.0190 | Total: 6.4533
#    ↳ AA sample loss: 0.023143 | AA cos loss: 0.002505
#
# [Summary] Epoch 21 Train Total Loss: 6.1620
# =======================================================================
#
# ===================== Epoch 22/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.1019 | I(t;y): 0.0000 | Recon: 0.0168 | Total: 5.9522
#    ↳ AA sample loss: 0.022989 | AA cos loss: 0.002007
# [Train] Batch 020 | I(t;x): 1.1073 | I(t;y): 0.0000 | Recon: 0.0179 | Total: 6.1894
#    ↳ AA sample loss: 0.022861 | AA cos loss: 0.002329
# [Train] Batch 030 | I(t;x): 1.0872 | I(t;y): 0.0000 | Recon: 0.0180 | Total: 6.1838
#    ↳ AA sample loss: 0.022713 | AA cos loss: 0.002243
# [Train] Batch 040 | I(t;x): 1.1026 | I(t;y): 0.0000 | Recon: 0.0172 | Total: 6.0314
#    ↳ AA sample loss: 0.022566 | AA cos loss: 0.002375
#
# [Summary] Epoch 22 Train Total Loss: 6.0705
# =======================================================================
#
# ===================== Epoch 23/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.0757 | I(t;y): 0.0000 | Recon: 0.0177 | Total: 6.0901
#    ↳ AA sample loss: 0.022495 | AA cos loss: 0.002155
# [Train] Batch 020 | I(t;x): 1.1080 | I(t;y): 0.0000 | Recon: 0.0164 | Total: 5.8837
#    ↳ AA sample loss: 0.022292 | AA cos loss: 0.002580
# [Train] Batch 030 | I(t;x): 1.0698 | I(t;y): 0.0000 | Recon: 0.0175 | Total: 6.0558
#    ↳ AA sample loss: 0.022150 | AA cos loss: 0.002555
# [Train] Batch 040 | I(t;x): 1.0734 | I(t;y): 0.0000 | Recon: 0.0176 | Total: 6.0569
#    ↳ AA sample loss: 0.022065 | AA cos loss: 0.002162
#
# [Summary] Epoch 23 Train Total Loss: 5.9746
# =======================================================================
#
# ===================== Epoch 24/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.0954 | I(t;y): 0.0000 | Recon: 0.0166 | Total: 5.8704
#    ↳ AA sample loss: 0.021856 | AA cos loss: 0.002503
# [Train] Batch 020 | I(t;x): 1.1406 | I(t;y): 0.0000 | Recon: 0.0174 | Total: 6.0611
#    ↳ AA sample loss: 0.021765 | AA cos loss: 0.002133
# [Train] Batch 030 | I(t;x): 1.0798 | I(t;y): 0.0000 | Recon: 0.0184 | Total: 6.2001
#    ↳ AA sample loss: 0.021527 | AA cos loss: 0.002463
# [Train] Batch 040 | I(t;x): 1.1389 | I(t;y): 0.0000 | Recon: 0.0169 | Total: 5.9316
#    ↳ AA sample loss: 0.021355 | AA cos loss: 0.002239
#
# [Summary] Epoch 24 Train Total Loss: 5.9241
# =======================================================================
#
# ===================== Epoch 25/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.0252 | I(t;y): 0.0000 | Recon: 0.0162 | Total: 5.6804
#    ↳ AA sample loss: 0.021094 | AA cos loss: 0.002540
# [Train] Batch 020 | I(t;x): 1.1008 | I(t;y): 0.0000 | Recon: 0.0173 | Total: 5.9625
#    ↳ AA sample loss: 0.020938 | AA cos loss: 0.002466
# [Train] Batch 030 | I(t;x): 1.1234 | I(t;y): 0.0000 | Recon: 0.0168 | Total: 5.8800
#    ↳ AA sample loss: 0.020839 | AA cos loss: 0.002317
# [Train] Batch 040 | I(t;x): 1.0860 | I(t;y): 0.0000 | Recon: 0.0167 | Total: 5.8096
#    ↳ AA sample loss: 0.020621 | AA cos loss: 0.002588
#
# [Summary] Epoch 25 Train Total Loss: 5.8576
# =======================================================================
#
# ===================== Epoch 26/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.0959 | I(t;y): 0.0000 | Recon: 0.0173 | Total: 5.9147
#    ↳ AA sample loss: 0.020550 | AA cos loss: 0.002177
# [Train] Batch 020 | I(t;x): 1.1108 | I(t;y): 0.0000 | Recon: 0.0169 | Total: 5.8528
#    ↳ AA sample loss: 0.020310 | AA cos loss: 0.002232
# [Train] Batch 030 | I(t;x): 1.0902 | I(t;y): 0.0000 | Recon: 0.0166 | Total: 5.7569
#    ↳ AA sample loss: 0.020114 | AA cos loss: 0.002468
# [Train] Batch 040 | I(t;x): 1.0988 | I(t;y): 0.0000 | Recon: 0.0162 | Total: 5.6822
#    ↳ AA sample loss: 0.019951 | AA cos loss: 0.002277
#
# [Summary] Epoch 26 Train Total Loss: 5.7559
# =======================================================================
#
# ===================== Epoch 27/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.1083 | I(t;y): 0.0000 | Recon: 0.0161 | Total: 5.6432
#    ↳ AA sample loss: 0.019776 | AA cos loss: 0.002225
# [Train] Batch 020 | I(t;x): 1.0707 | I(t;y): 0.0000 | Recon: 0.0168 | Total: 5.7403
#    ↳ AA sample loss: 0.019488 | AA cos loss: 0.002438
# [Train] Batch 030 | I(t;x): 1.1064 | I(t;y): 0.0000 | Recon: 0.0165 | Total: 5.6935
#    ↳ AA sample loss: 0.019366 | AA cos loss: 0.002198
# [Train] Batch 040 | I(t;x): 1.0827 | I(t;y): 0.0000 | Recon: 0.0173 | Total: 5.8221
#    ↳ AA sample loss: 0.019111 | AA cos loss: 0.002290
#
# [Summary] Epoch 27 Train Total Loss: 5.6651
# =======================================================================
#
# ===================== Epoch 28/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.0877 | I(t;y): 0.0000 | Recon: 0.0156 | Total: 5.4839
#    ↳ AA sample loss: 0.018829 | AA cos loss: 0.002412
# [Train] Batch 020 | I(t;x): 1.0968 | I(t;y): 0.0000 | Recon: 0.0161 | Total: 5.5621
#    ↳ AA sample loss: 0.018573 | AA cos loss: 0.002266
# [Train] Batch 030 | I(t;x): 1.1310 | I(t;y): 0.0000 | Recon: 0.0161 | Total: 5.5838
#    ↳ AA sample loss: 0.018486 | AA cos loss: 0.002191
# [Train] Batch 040 | I(t;x): 1.0791 | I(t;y): 0.0000 | Recon: 0.0166 | Total: 5.6333
#    ↳ AA sample loss: 0.018285 | AA cos loss: 0.002370
#
# [Summary] Epoch 28 Train Total Loss: 5.6217
# =======================================================================
#
# ===================== Epoch 29/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.1183 | I(t;y): 0.0000 | Recon: 0.0158 | Total: 5.4947
#    ↳ AA sample loss: 0.018115 | AA cos loss: 0.002257
# [Train] Batch 020 | I(t;x): 1.1322 | I(t;y): 0.0000 | Recon: 0.0165 | Total: 5.6464
#    ↳ AA sample loss: 0.017811 | AA cos loss: 0.002278
# [Train] Batch 030 | I(t;x): 1.1018 | I(t;y): 0.0000 | Recon: 0.0171 | Total: 5.7157
#    ↳ AA sample loss: 0.017532 | AA cos loss: 0.002477
# [Train] Batch 040 | I(t;x): 1.0858 | I(t;y): 0.0000 | Recon: 0.0157 | Total: 5.4049
#    ↳ AA sample loss: 0.017278 | AA cos loss: 0.002444
#
# [Summary] Epoch 29 Train Total Loss: 5.5715
# =======================================================================
#
# ===================== Epoch 30/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.0741 | I(t;y): 0.0000 | Recon: 0.0159 | Total: 5.4181
#    ↳ AA sample loss: 0.017146 | AA cos loss: 0.002326
# [Train] Batch 020 | I(t;x): 1.0900 | I(t;y): 0.0000 | Recon: 0.0157 | Total: 5.3815
#    ↳ AA sample loss: 0.016917 | AA cos loss: 0.002367
# [Train] Batch 030 | I(t;x): 1.0907 | I(t;y): 0.0000 | Recon: 0.0156 | Total: 5.3665
#    ↳ AA sample loss: 0.016770 | AA cos loss: 0.002426
# [Train] Batch 040 | I(t;x): 1.0917 | I(t;y): 0.0000 | Recon: 0.0159 | Total: 5.3971
#    ↳ AA sample loss: 0.016546 | AA cos loss: 0.002194
#
# [Summary] Epoch 30 Train Total Loss: 5.4500
# =======================================================================
#
# ===================== Epoch 31/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.0977 | I(t;y): 0.0000 | Recon: 0.0163 | Total: 5.4932
#    ↳ AA sample loss: 0.016282 | AA cos loss: 0.002485
# [Train] Batch 020 | I(t;x): 1.0967 | I(t;y): 0.0000 | Recon: 0.0158 | Total: 5.3645
#    ↳ AA sample loss: 0.016075 | AA cos loss: 0.002310
# [Train] Batch 030 | I(t;x): 1.0829 | I(t;y): 0.0000 | Recon: 0.0157 | Total: 5.3066
#    ↳ AA sample loss: 0.015863 | AA cos loss: 0.002219
# [Train] Batch 040 | I(t;x): 1.1352 | I(t;y): 0.0000 | Recon: 0.0156 | Total: 5.3336
#    ↳ AA sample loss: 0.015602 | AA cos loss: 0.002464
#
# [Summary] Epoch 31 Train Total Loss: 5.3939
# =======================================================================
#
# ===================== Epoch 32/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.1217 | I(t;y): 0.0000 | Recon: 0.0159 | Total: 5.3719
#    ↳ AA sample loss: 0.015469 | AA cos loss: 0.002427
# [Train] Batch 020 | I(t;x): 1.0969 | I(t;y): 0.0000 | Recon: 0.0160 | Total: 5.3758
#    ↳ AA sample loss: 0.015206 | AA cos loss: 0.002639
# [Train] Batch 030 | I(t;x): 1.0864 | I(t;y): 0.0000 | Recon: 0.0152 | Total: 5.1706
#    ↳ AA sample loss: 0.014896 | AA cos loss: 0.002470
# [Train] Batch 040 | I(t;x): 1.1105 | I(t;y): 0.0000 | Recon: 0.0161 | Total: 5.3575
#    ↳ AA sample loss: 0.014818 | AA cos loss: 0.002299
#
# [Summary] Epoch 32 Train Total Loss: 5.3149
# =======================================================================
#
# ===================== Epoch 33/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.1418 | I(t;y): 0.0000 | Recon: 0.0162 | Total: 5.4069
#    ↳ AA sample loss: 0.014566 | AA cos loss: 0.002486
# [Train] Batch 020 | I(t;x): 1.1158 | I(t;y): 0.0000 | Recon: 0.0156 | Total: 5.2510
#    ↳ AA sample loss: 0.014444 | AA cos loss: 0.002476
# [Train] Batch 030 | I(t;x): 1.1059 | I(t;y): 0.0000 | Recon: 0.0156 | Total: 5.2206
#    ↳ AA sample loss: 0.014222 | AA cos loss: 0.002369
# [Train] Batch 040 | I(t;x): 1.0967 | I(t;y): 0.0000 | Recon: 0.0157 | Total: 5.2366
#    ↳ AA sample loss: 0.014025 | AA cos loss: 0.002492
#
# [Summary] Epoch 33 Train Total Loss: 5.2615
# =======================================================================
#
# ===================== Epoch 34/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.1134 | I(t;y): 0.0000 | Recon: 0.0151 | Total: 5.0906
#    ↳ AA sample loss: 0.013898 | AA cos loss: 0.002118
# [Train] Batch 020 | I(t;x): 1.0975 | I(t;y): 0.0000 | Recon: 0.0160 | Total: 5.2616
#    ↳ AA sample loss: 0.013745 | AA cos loss: 0.002384
# [Train] Batch 030 | I(t;x): 1.1025 | I(t;y): 0.0000 | Recon: 0.0156 | Total: 5.1687
#    ↳ AA sample loss: 0.013503 | AA cos loss: 0.002189
# [Train] Batch 040 | I(t;x): 1.1169 | I(t;y): 0.0000 | Recon: 0.0159 | Total: 5.2340
#    ↳ AA sample loss: 0.013233 | AA cos loss: 0.002538
#
# [Summary] Epoch 34 Train Total Loss: 5.1894
# =======================================================================
#
# ===================== Epoch 35/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.1049 | I(t;y): 0.0000 | Recon: 0.0154 | Total: 5.1149
#    ↳ AA sample loss: 0.013213 | AA cos loss: 0.002364
# [Train] Batch 020 | I(t;x): 1.1244 | I(t;y): 0.0000 | Recon: 0.0162 | Total: 5.2879
#    ↳ AA sample loss: 0.013027 | AA cos loss: 0.002387
# [Train] Batch 030 | I(t;x): 1.1053 | I(t;y): 0.0000 | Recon: 0.0159 | Total: 5.2015
#    ↳ AA sample loss: 0.012875 | AA cos loss: 0.002441
# [Train] Batch 040 | I(t;x): 1.1117 | I(t;y): 0.0000 | Recon: 0.0157 | Total: 5.1497
#    ↳ AA sample loss: 0.012700 | AA cos loss: 0.002227
#
# [Summary] Epoch 35 Train Total Loss: 5.1379
# =======================================================================
#
# ===================== Epoch 36/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.1173 | I(t;y): 0.0000 | Recon: 0.0162 | Total: 5.2600
#    ↳ AA sample loss: 0.012470 | AA cos loss: 0.002507
# [Train] Batch 020 | I(t;x): 1.1101 | I(t;y): 0.0000 | Recon: 0.0160 | Total: 5.2121
#    ↳ AA sample loss: 0.012368 | AA cos loss: 0.002611
# [Train] Batch 030 | I(t;x): 1.1207 | I(t;y): 0.0000 | Recon: 0.0160 | Total: 5.1911
#    ↳ AA sample loss: 0.012291 | AA cos loss: 0.002376
# [Train] Batch 040 | I(t;x): 1.1341 | I(t;y): 0.0000 | Recon: 0.0151 | Total: 5.0048
#    ↳ AA sample loss: 0.012061 | AA cos loss: 0.002215
#
# [Summary] Epoch 36 Train Total Loss: 5.1025
# =======================================================================
#
# ===================== Epoch 37/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.1112 | I(t;y): 0.0000 | Recon: 0.0163 | Total: 5.2200
#    ↳ AA sample loss: 0.011983 | AA cos loss: 0.002291
# [Train] Batch 020 | I(t;x): 1.0990 | I(t;y): 0.0000 | Recon: 0.0150 | Total: 4.9337
#    ↳ AA sample loss: 0.011761 | AA cos loss: 0.002281
# [Train] Batch 030 | I(t;x): 1.1201 | I(t;y): 0.0000 | Recon: 0.0153 | Total: 5.0326
#    ↳ AA sample loss: 0.011664 | AA cos loss: 0.002427
# [Train] Batch 040 | I(t;x): 1.1216 | I(t;y): 0.0000 | Recon: 0.0156 | Total: 5.0731
#    ↳ AA sample loss: 0.011594 | AA cos loss: 0.002300
#
# [Summary] Epoch 37 Train Total Loss: 5.0499
# =======================================================================
#
# ===================== Epoch 38/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.1104 | I(t;y): 0.0000 | Recon: 0.0153 | Total: 4.9965
#    ↳ AA sample loss: 0.011442 | AA cos loss: 0.002363
# [Train] Batch 020 | I(t;x): 1.1097 | I(t;y): 0.0000 | Recon: 0.0151 | Total: 4.9663
#    ↳ AA sample loss: 0.011246 | AA cos loss: 0.002610
# [Train] Batch 030 | I(t;x): 1.1267 | I(t;y): 0.0000 | Recon: 0.0154 | Total: 5.0357
#    ↳ AA sample loss: 0.011241 | AA cos loss: 0.002607
# [Train] Batch 040 | I(t;x): 1.1203 | I(t;y): 0.0000 | Recon: 0.0156 | Total: 5.0478
#    ↳ AA sample loss: 0.011108 | AA cos loss: 0.002436
#
# [Summary] Epoch 38 Train Total Loss: 5.0393
# =======================================================================
#
# ===================== Epoch 39/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.1008 | I(t;y): 0.0000 | Recon: 0.0152 | Total: 4.9463
#    ↳ AA sample loss: 0.011000 | AA cos loss: 0.002406
# [Train] Batch 020 | I(t;x): 1.1206 | I(t;y): 0.0000 | Recon: 0.0152 | Total: 4.9592
#    ↳ AA sample loss: 0.010909 | AA cos loss: 0.002314
# [Train] Batch 030 | I(t;x): 1.1127 | I(t;y): 0.0000 | Recon: 0.0154 | Total: 4.9631
#    ↳ AA sample loss: 0.010744 | AA cos loss: 0.002250
# [Train] Batch 040 | I(t;x): 1.1393 | I(t;y): 0.0000 | Recon: 0.0162 | Total: 5.1868
#    ↳ AA sample loss: 0.010757 | AA cos loss: 0.002649
#
# [Summary] Epoch 39 Train Total Loss: 4.9823
# =======================================================================
#
# ===================== Epoch 40/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.1261 | I(t;y): 0.0000 | Recon: 0.0149 | Total: 4.8992
#    ↳ AA sample loss: 0.010533 | AA cos loss: 0.002714
# [Train] Batch 020 | I(t;x): 1.1283 | I(t;y): 0.0000 | Recon: 0.0161 | Total: 5.1349
#    ↳ AA sample loss: 0.010491 | AA cos loss: 0.002479
# [Train] Batch 030 | I(t;x): 1.1270 | I(t;y): 0.0000 | Recon: 0.0149 | Total: 4.8706
#    ↳ AA sample loss: 0.010439 | AA cos loss: 0.002269
# [Train] Batch 040 | I(t;x): 1.1434 | I(t;y): 0.0000 | Recon: 0.0159 | Total: 5.0833
#    ↳ AA sample loss: 0.010400 | AA cos loss: 0.002287
#
# [Summary] Epoch 40 Train Total Loss: 4.9673
# =======================================================================
#
# ===================== Epoch 41/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.1251 | I(t;y): 0.0000 | Recon: 0.0148 | Total: 4.8529
#    ↳ AA sample loss: 0.010309 | AA cos loss: 0.002375
# [Train] Batch 020 | I(t;x): 1.1169 | I(t;y): 0.0000 | Recon: 0.0157 | Total: 5.0274
#    ↳ AA sample loss: 0.010220 | AA cos loss: 0.002459
# [Train] Batch 030 | I(t;x): 1.1076 | I(t;y): 0.0000 | Recon: 0.0145 | Total: 4.7536
#    ↳ AA sample loss: 0.010113 | AA cos loss: 0.002332
# [Train] Batch 040 | I(t;x): 1.1081 | I(t;y): 0.0000 | Recon: 0.0155 | Total: 4.9497
#    ↳ AA sample loss: 0.010054 | AA cos loss: 0.002410
#
# [Summary] Epoch 41 Train Total Loss: 4.9329
# =======================================================================
#
# ===================== Epoch 42/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.1420 | I(t;y): 0.0000 | Recon: 0.0150 | Total: 4.9017
#    ↳ AA sample loss: 0.009932 | AA cos loss: 0.002606
# [Train] Batch 020 | I(t;x): 1.1252 | I(t;y): 0.0000 | Recon: 0.0152 | Total: 4.8943
#    ↳ AA sample loss: 0.009892 | AA cos loss: 0.002406
# [Train] Batch 030 | I(t;x): 1.1205 | I(t;y): 0.0000 | Recon: 0.0150 | Total: 4.8494
#    ↳ AA sample loss: 0.009848 | AA cos loss: 0.002189
# [Train] Batch 040 | I(t;x): 1.1217 | I(t;y): 0.0000 | Recon: 0.0154 | Total: 4.9321
#    ↳ AA sample loss: 0.009704 | AA cos loss: 0.002497
#
# [Summary] Epoch 42 Train Total Loss: 4.9013
# =======================================================================
#
# ===================== Epoch 43/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.1266 | I(t;y): 0.0000 | Recon: 0.0149 | Total: 4.8241
#    ↳ AA sample loss: 0.009673 | AA cos loss: 0.002282
# [Train] Batch 020 | I(t;x): 1.1295 | I(t;y): 0.0000 | Recon: 0.0151 | Total: 4.8818
#    ↳ AA sample loss: 0.009588 | AA cos loss: 0.002466
# [Train] Batch 030 | I(t;x): 1.1369 | I(t;y): 0.0000 | Recon: 0.0151 | Total: 4.8613
#    ↳ AA sample loss: 0.009571 | AA cos loss: 0.002316
# [Train] Batch 040 | I(t;x): 1.1121 | I(t;y): 0.0000 | Recon: 0.0149 | Total: 4.7933
#    ↳ AA sample loss: 0.009411 | AA cos loss: 0.002437
#
# [Summary] Epoch 43 Train Total Loss: 4.8585
# =======================================================================
#
# ===================== Epoch 44/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.1092 | I(t;y): 0.0000 | Recon: 0.0156 | Total: 4.9206
#    ↳ AA sample loss: 0.009393 | AA cos loss: 0.002214
# [Train] Batch 020 | I(t;x): 1.1235 | I(t;y): 0.0000 | Recon: 0.0150 | Total: 4.8196
#    ↳ AA sample loss: 0.009385 | AA cos loss: 0.002356
# [Train] Batch 030 | I(t;x): 1.1458 | I(t;y): 0.0000 | Recon: 0.0148 | Total: 4.8053
#    ↳ AA sample loss: 0.009222 | AA cos loss: 0.002349
# [Train] Batch 040 | I(t;x): 1.1556 | I(t;y): 0.0000 | Recon: 0.0151 | Total: 4.8753
#    ↳ AA sample loss: 0.009235 | AA cos loss: 0.002438
#
# [Summary] Epoch 44 Train Total Loss: 4.8328
# =======================================================================
#
# ===================== Epoch 45/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.1293 | I(t;y): 0.0000 | Recon: 0.0154 | Total: 4.9005
#    ↳ AA sample loss: 0.009132 | AA cos loss: 0.002543
# [Train] Batch 020 | I(t;x): 1.1062 | I(t;y): 0.0000 | Recon: 0.0147 | Total: 4.7335
#    ↳ AA sample loss: 0.009075 | AA cos loss: 0.002361
# [Train] Batch 030 | I(t;x): 1.1493 | I(t;y): 0.0000 | Recon: 0.0150 | Total: 4.8127
#    ↳ AA sample loss: 0.008980 | AA cos loss: 0.002237
# [Train] Batch 040 | I(t;x): 1.1268 | I(t;y): 0.0000 | Recon: 0.0152 | Total: 4.8545
#    ↳ AA sample loss: 0.008912 | AA cos loss: 0.002452
#
# [Summary] Epoch 45 Train Total Loss: 4.8028
# =======================================================================
#
# ===================== Epoch 46/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.1303 | I(t;y): 0.0000 | Recon: 0.0158 | Total: 4.9698
#    ↳ AA sample loss: 0.008849 | AA cos loss: 0.002501
# [Train] Batch 020 | I(t;x): 1.1068 | I(t;y): 0.0000 | Recon: 0.0148 | Total: 4.7333
#    ↳ AA sample loss: 0.008819 | AA cos loss: 0.002350
# [Train] Batch 030 | I(t;x): 1.1407 | I(t;y): 0.0000 | Recon: 0.0147 | Total: 4.7460
#    ↳ AA sample loss: 0.008718 | AA cos loss: 0.002330
# [Train] Batch 040 | I(t;x): 1.1349 | I(t;y): 0.0000 | Recon: 0.0164 | Total: 5.0883
#    ↳ AA sample loss: 0.008702 | AA cos loss: 0.002651
#
# [Summary] Epoch 46 Train Total Loss: 4.8104
# =======================================================================
#
# ===================== Epoch 47/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.1237 | I(t;y): 0.0000 | Recon: 0.0152 | Total: 4.8346
#    ↳ AA sample loss: 0.008608 | AA cos loss: 0.002524
# [Train] Batch 020 | I(t;x): 1.1387 | I(t;y): 0.0000 | Recon: 0.0163 | Total: 5.0622
#    ↳ AA sample loss: 0.008641 | AA cos loss: 0.002419
# [Train] Batch 030 | I(t;x): 1.1520 | I(t;y): 0.0000 | Recon: 0.0152 | Total: 4.8569
#    ↳ AA sample loss: 0.008543 | AA cos loss: 0.002426
# [Train] Batch 040 | I(t;x): 1.1428 | I(t;y): 0.0000 | Recon: 0.0142 | Total: 4.6258
#    ↳ AA sample loss: 0.008502 | AA cos loss: 0.002371
#
# [Summary] Epoch 47 Train Total Loss: 4.7781
# =======================================================================
#
# ===================== Epoch 48/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.1602 | I(t;y): 0.0000 | Recon: 0.0157 | Total: 4.9503
#    ↳ AA sample loss: 0.008490 | AA cos loss: 0.002452
# [Train] Batch 020 | I(t;x): 1.1560 | I(t;y): 0.0000 | Recon: 0.0144 | Total: 4.6748
#    ↳ AA sample loss: 0.008351 | AA cos loss: 0.002314
# [Train] Batch 030 | I(t;x): 1.1532 | I(t;y): 0.0000 | Recon: 0.0150 | Total: 4.7833
#    ↳ AA sample loss: 0.008385 | AA cos loss: 0.002226
# [Train] Batch 040 | I(t;x): 1.1317 | I(t;y): 0.0000 | Recon: 0.0140 | Total: 4.5746
#    ↳ AA sample loss: 0.008268 | AA cos loss: 0.002333
#
# [Summary] Epoch 48 Train Total Loss: 4.7489
# =======================================================================
#
# ===================== Epoch 49/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.1428 | I(t;y): 0.0000 | Recon: 0.0145 | Total: 4.6659
#    ↳ AA sample loss: 0.008219 | AA cos loss: 0.002183
# [Train] Batch 020 | I(t;x): 1.1540 | I(t;y): 0.0000 | Recon: 0.0149 | Total: 4.7576
#    ↳ AA sample loss: 0.008185 | AA cos loss: 0.002285
# [Train] Batch 030 | I(t;x): 1.1250 | I(t;y): 0.0000 | Recon: 0.0145 | Total: 4.6504
#    ↳ AA sample loss: 0.008150 | AA cos loss: 0.002262
# [Train] Batch 040 | I(t;x): 1.1407 | I(t;y): 0.0000 | Recon: 0.0143 | Total: 4.6167
#    ↳ AA sample loss: 0.008110 | AA cos loss: 0.002233
#
# [Summary] Epoch 49 Train Total Loss: 4.7166
# =======================================================================
#
# ===================== Epoch 50/50 =====================
# Mode: Full (KL + Recon + MI + full AA reconstruction + cos loss)
# [Train] Batch 010 | I(t;x): 1.1245 | I(t;y): 0.0000 | Recon: 0.0146 | Total: 4.6758
#    ↳ AA sample loss: 0.007998 | AA cos loss: 0.002382
# [Train] Batch 020 | I(t;x): 1.1193 | I(t;y): 0.0000 | Recon: 0.0146 | Total: 4.6787
#    ↳ AA sample loss: 0.008016 | AA cos loss: 0.002528
# [Train] Batch 030 | I(t;x): 1.1244 | I(t;y): 0.0000 | Recon: 0.0139 | Total: 4.5195
#    ↳ AA sample loss: 0.008022 | AA cos loss: 0.002342
# [Train] Batch 040 | I(t;x): 1.1557 | I(t;y): 0.0000 | Recon: 0.0152 | Total: 4.8200
#    ↳ AA sample loss: 0.007935 | AA cos loss: 0.002362
#
# [Summary] Epoch 50 Train Total Loss: 4.6806
# =======================================================================
#
# [Save] Epoch losses saved to: ./results/mnist_notebook_seed42_aa5\epoch_total_losses.pkl
# [Save] Archetypes & decoded saved in: ./results/mnist_notebook_seed42_aa5
# [Save] Final model saved to: ./results/mnist_notebook_seed42_aa5
# [Save] Full model (with archetypes & AA mapping) saved to: ./results/mnist_notebook_seed42_aa5
#
# [PostProcess] Saving full latent reconstruction results (correct AA reconstruction) ...
# [Done] AA reconstruction results saved to: ./results/mnist_notebook_seed42_aa5
# Average AA reconstruction MSE = 0.032127

# %%
from utils.visualization import plot_decoded_archetypes
plot_decoded_archetypes("results/mnist_notebook_seed42_aa5")

# %%
from utils.visualization import visualize_latent_archetypes_3d

visualize_latent_archetypes_3d(
    exp_dir="results/mnist_notebook_seed42_aa5",
    dataset="mnist",
    latent_dim=32,
    seed=42
)

# %%
import numpy as np
from torchvision import datasets, transforms
import os

def evaluate_reconstruction_from_saved(exp_dir="./results/mnist_notebook_seed42_aa5", dataset="mnist"):
    """
    Function: Calculate MSE between original images, direct reconstruction, and AA reconstruction from saved decoded files (supports MNIST/KMNIST)
    Parameters:
        - exp_dir: Directory where result files are stored
        - dataset: Dataset type ("mnist" or "kmnist")
    """
    # -----------------------------
    # Load dataset (distinguish between MNIST/KMNIST)
    # -----------------------------
    transform = transforms.Compose([transforms.ToTensor()])
    if dataset == "mnist":
        ds = datasets.MNIST("./data", train=True, transform=transform, download=True)
    elif dataset == "kmnist":
        ds = datasets.KMNIST("./data", train=True, transform=transform, download=True)
    else:
        raise ValueError("dataset only supports 'mnist' or 'kmnist'")

    # -----------------------------
    # Load original images and labels
    # -----------------------------
    X = np.stack([img.numpy() for img, _ in ds])  # Original images, shape: (N,1,28,28)
    y = np.array([label for _, label in ds])      # Sample labels

    # -----------------------------
    # Load saved reconstruction result files
    # -----------------------------
    direct_recon = np.load(os.path.join(exp_dir, "decoded_mu.npy"))    # Direct reconstruction result (model output)
    aa_recon = np.load(os.path.join(exp_dir, "decoded_mu_AA.npy"))     # AA reconstructed result

    # -----------------------------
    # Calculate MSE (Mean Squared Error) for each sample
    # -----------------------------
    mse_direct = np.mean((direct_recon - X) ** 2, axis=(1,2,3))  # MSE of direct reconstruction
    mse_aa = np.mean((aa_recon - X) ** 2, axis=(1,2,3))          # MSE of AA reconstruction

    # -----------------------------
    # Calculate average MSE per class
    # -----------------------------
    results = {
        int(c): {
            "Direct": mse_direct[y == c].mean(),
            "AA": mse_aa[y == c].mean()
        }
        for c in np.unique(y)
    }
    # Calculate overall average MSE
    results["ALL"] = {
        "Direct": mse_direct.mean(),
        "AA": mse_aa.mean()
    }

    # -----------------------------
    # Output results (English format)
    # -----------------------------
    print(f"\n==== {dataset.upper()} Reconstruction MSE ====")
    for c in sorted(k for k in results.keys() if isinstance(k, int)):
        print(f"Class {c}: Direct={results[c]['Direct']:.6f} | AA={results[c]['AA']:.6f}")
    print(f"Overall: Direct={results['ALL']['Direct']:.6f} | AA={results['ALL']['AA']:.6f}")
    print("=============================================")

# %%
from utils.evaluation import evaluate_reconstruction_from_saved
evaluate_reconstruction_from_saved(
    exp_dir="./results/mnist_notebook_seed42_aa5",
    dataset="mnist"
)
# Out:
# ==== MNIST Reconstruction MSE ====
# Class 0: Direct=0.016932 | AA=0.034766
# Class 1: Direct=0.007197 | AA=0.013729
# Class 2: Direct=0.030083 | AA=0.042238
# Class 3: Direct=0.026991 | AA=0.039562
# Class 4: Direct=0.019213 | AA=0.032461
# Class 5: Direct=0.022057 | AA=0.033611
# Class 6: Direct=0.018744 | AA=0.033553
# Class 7: Direct=0.014973 | AA=0.027546
# Class 8: Direct=0.030201 | AA=0.040194
# Class 9: Direct=0.016178 | AA=0.026352
# Overall: Direct=0.020050 | AA=0.032127
# =============================================

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torchvision import datasets, transforms
import os

def visualize_digits_grid(exp_dir="./results/mnist_notebook_seed42_aa5", dataset="mnist"):
    """
    Display 10 digits (0–9), one per column:
    Row 1: Original images
    Row 2: Direct reconstruction
    Row 3: AA reconstruction
    Each column shows the label and two types of MSE.
    Uses the first sample of each label from the training set.
    """
    # Load dataset
    transform = transforms.Compose([transforms.ToTensor()])
    if dataset == "mnist":
        ds_train = datasets.MNIST("./data", train=True, transform=transform, download=True)
    elif dataset == "kmnist":
        ds_train = datasets.KMNIST("./data", train=True, transform=transform, download=True)
    else:
        raise ValueError("dataset only supports 'mnist' or 'kmnist'")

    # Load saved reconstruction results
    decoded_mu = np.load(os.path.join(exp_dir, "decoded_mu.npy"))
    decoded_mu_AA = np.load(os.path.join(exp_dir, "decoded_mu_AA.npy"))

    # Original images and labels
    imgs = np.stack([img.numpy() for img, _ in ds_train])
    labels = np.array([lbl for _, lbl in ds_train])

    # Select a representative sample for each digit (take the first occurrence)
    selected_idxs = [np.where(labels == d)[0][0] for d in range(10)]

    # Create figure and axes
    fig, axes = plt.subplots(3, 10, figsize=(20, 6))

    for col, idx in enumerate(selected_idxs):
        lbl = labels[idx]
        orig = imgs[idx, 0]
        recon = decoded_mu[idx, 0]
        aa_recon = decoded_mu_AA[idx, 0]

        mse_direct = np.mean((recon - orig) ** 2)
        mse_aa = np.mean((aa_recon - orig) ** 2)

        # Row 1: Original image
        axes[0, col].imshow(orig, cmap="gray")
        axes[0, col].set_title(f"Label: {lbl}", fontsize=10)
        axes[0, col].axis("off")

        # Row 2: Direct reconstruction
        axes[1, col].imshow(recon, cmap="gray")
        axes[1, col].set_title(f"Direct\nMSE: {mse_direct:.4f}", fontsize=8, color="blue")
        axes[1, col].axis("off")

        # Row 3: AA reconstruction
        axes[2, col].imshow(aa_recon, cmap="gray")
        axes[2, col].set_title(f"AA\nMSE: {mse_aa:.4f}", fontsize=8, color="red")
        axes[2, col].axis("off")

    # fig.suptitle("Digits 0–9: Original / Direct Reconstruction / AA Reconstruction", fontsize=14)
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.show()

visualize_digits_grid(
    exp_dir="./results/mnist_notebook_seed42_aa5",
    dataset="mnist"
)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from torchvision import datasets, transforms
import os

def visualize_classwise_aa_usage(exp_dir="./results/mnist_notebook_seed42_aa5"):

    mu = np.load(os.path.join(exp_dir, "latent_mu.npy"))
    mu_aa = np.load(os.path.join(exp_dir, "latent_mu_AA.npy"))
    arch = np.load(os.path.join(exp_dir, "final_archetypes.npy"))

    arch_pinv = np.linalg.pinv(arch)
    W_est = mu_aa @ arch_pinv
    W_est = np.clip(W_est, 1e-8, None)
    W_est /= W_est.sum(axis=1, keepdims=True)

    transform = transforms.Compose([transforms.ToTensor()])
    ds = datasets.MNIST("./data", train=True, download=True, transform=transform)
    y = np.array([label for _, label in ds])

    num_classes = 10
    heatmap_data = np.zeros((num_classes, W_est.shape[1]))
    for c in range(num_classes):
        heatmap_data[c] = W_est[y == c].mean(axis=0)

    plt.figure(figsize=(12, 6))
    sns.heatmap(heatmap_data, cmap="YlGnBu", xticklabels=False, cbar=False)
    # plt.title("Class-wise Archetype Usage (mean softmax weights)")
    plt.xlabel("Archetype index")
    plt.ylabel("Digit class (0–9)")
    plt.show()


# -----------------------------
visualize_classwise_aa_usage(
    exp_dir="./results/mnist_notebook_seed42_aa5"
)

# %% [markdown]
# # Linear AA

# %%
import numpy as np
import matplotlib.pyplot as plt
from py_pcha import PCHA
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from sklearn.decomposition import PCA
import torch, random, warnings, os

# =========================
# Global Archetypal Analysis (PCA-32D)
# =========================

# ----------------------------
# Config 
# ----------------------------
warnings.filterwarnings("ignore", category=UserWarning)

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
set_seed(42)

save_dir = "./results/mnist_linear_AA"
os.makedirs(save_dir, exist_ok=True)

# ----------------------------
# Load dataset 
# ----------------------------
transform = transforms.Compose([transforms.ToTensor()])
ds_train = datasets.MNIST("./data", train=True, transform=transform, download=True)

X_train = np.array([img.numpy().flatten() for img, _ in ds_train])
y_train = np.array([label for _, label in ds_train])

# ----------------------------
# PCA dimensionality reduction 
# ----------------------------
PCA_DIMS = 32
pca = PCA(n_components=PCA_DIMS, random_state=42)
Z_train = pca.fit_transform(X_train)

# ----------------------------
# Global AA training 
# ----------------------------
N_ARCHETYPES = 50  
XC, S, C, SSE, varexpl = PCHA(
    X=Z_train.T, noc=N_ARCHETYPES, maxiter=1000, verbose=False
)

# ----------------------------
# Decode archetypes 
A_global = pca.inverse_transform(XC.T)

# ----------------------------
# Save all results 
np.save(os.path.join(save_dir, "A_global.npy"), A_global)
np.save(os.path.join(save_dir, "Z_train.npy"), Z_train)
np.save(os.path.join(save_dir, "XC_latent.npy"), XC)
np.save(os.path.join(save_dir, "S_coeff.npy"), S)
np.save(os.path.join(save_dir, "C_coeff.npy"), C)
np.save(os.path.join(save_dir, "SSE.npy"), np.array([SSE]))
np.save(os.path.join(save_dir, "varexpl.npy"), np.array([varexpl]))
np.save(os.path.join(save_dir, "labels.npy"), y_train)

print("results saved to:", save_dir)
print(f"XC (latent archetypes): {XC.shape}")
print(f"S (weights): {S.shape}")
print(f"C (convex coeff): {C.shape}")
print(f"A_global (pixel archetypes): {A_global.shape}")
print(f"SSE={SSE:.4f}, var explained={varexpl:.4f}")

# ----------------------------
# Visualization 
# ----------------------------
n_cols = 10
n_rows = N_ARCHETYPES // n_cols
fig, axes = plt.subplots(n_rows, n_cols, figsize=(n_cols * 1.2, n_rows * 1.2))

for i, ax in enumerate(axes.flat):
    if i < N_ARCHETYPES:
        img = A_global[i].reshape(28, 28)
        ax.imshow(img, cmap="gray")
        ax.set_title(f"AA {i}", fontsize=6)
    ax.set_axis_off()

plt.tight_layout(pad=0.3, h_pad=0.4, w_pad=0.2)
plt.show()
# Out:
# results saved to: ./results/mnist_linear_AA
# XC (latent archetypes): (32, 50)
# S (weights): (50, 60000)
# C (convex coeff): (60000, 50)
# A_global (pixel archetypes): (50, 784)
# SSE=657753.9546, var explained=0.7204

# %%
import joblib
from sklearn.decomposition import PCA
import numpy as np
from torchvision import datasets, transforms

transform = transforms.Compose([transforms.ToTensor()])
ds_train = datasets.MNIST("./data", train=True, transform=transform, download=True)
X_pixel = np.array([img.numpy().flatten() for img, _ in ds_train])

pca = PCA(n_components=32, random_state=42)
pca.fit(X_pixel)

joblib.dump(pca, "./results/mnist_linear_AA/pca_model.pkl")
print("PCA model saved to ./results/mnist_linear_AA/pca_model.pkl")
# Out:
# PCA model saved to ./results/mnist_linear_AA/pca_model.pkl

# %%
from sklearn.manifold import TSNE
from mpl_toolkits.mplot3d import Axes3D
from scipy.spatial import ConvexHull
import numpy as np
import matplotlib.pyplot as plt

def visualize_tsne_pca_global_aa_hull(Z_train, y_train, A_global, pca, n_samples=2000):
    """Visualize 3D t-SNE of PCA latent space and AA convex hull """
    np.random.seed(42)

    idx = np.random.choice(len(Z_train), min(n_samples, len(Z_train)), replace=False)
    Z_sample = np.asarray(Z_train[idx])
    y_sample = np.asarray(y_train[idx])

    arch_all = np.asarray(pca.transform(np.asarray(A_global)))

    Z_joint = np.vstack([Z_sample, arch_all])
    tsne = TSNE(n_components=3, init="pca", random_state=42, perplexity=30)
    Z_emb = tsne.fit_transform(Z_joint)
    Z_emb_data = Z_emb[:len(Z_sample)]
    Z_emb_aa = Z_emb[len(Z_sample):]

    hull = ConvexHull(Z_emb_aa)

    fig = plt.figure(figsize=(8, 6))
    ax = fig.add_subplot(111, projection='3d')

    ax.scatter(Z_emb_data[:, 0], Z_emb_data[:, 1], Z_emb_data[:, 2],
               s=5, alpha=0.2, color='gray', label='Samples')

    ax.scatter(Z_emb_aa[:, 0], Z_emb_aa[:, 1], Z_emb_aa[:, 2],
               marker='^', s=60, color='red', edgecolors='k', linewidths=0.5, label='AA Points')

    for simplex in hull.simplices:
        pts = Z_emb_aa[simplex]
        ax.plot(pts[:, 0], pts[:, 1], pts[:, 2], 'r-', linewidth=0.8, alpha=0.7)

    ax.set_title("3D t-SNE of Global AA Archetypes with Convex Hull", fontsize=12)
    ax.legend(loc='upper left', fontsize=8)
    ax.grid(False)
    ax.set_xticks([]); ax.set_yticks([]); ax.set_zticks([])
    plt.tight_layout()
    plt.show()

visualize_tsne_pca_global_aa_hull(Z_train, y_train, A_global, pca, n_samples=2000)

# %%
import numpy as np
import joblib
import os

# =========================
save_dir = "./results/mnist_linear_AA"
pca = joblib.load(f"{save_dir}/pca_model.pkl")
Z_train = np.load(f"{save_dir}/Z_train.npy")      # (60000, 32)
y_train = np.load(f"{save_dir}/labels.npy")
A_global = np.load(f"{save_dir}/A_global.npy")    # (50, 784)
XC = np.load(f"{save_dir}/XC_latent.npy")         # (32, 50)
S = np.load(f"{save_dir}/S_coeff.npy")            # (50, 60000)

# =========================
from torchvision import datasets, transforms
transform = transforms.Compose([transforms.ToTensor()])
ds_train = datasets.MNIST("./data", train=True, transform=transform, download=True)
X_train = np.array([img.numpy().flatten() for img, _ in ds_train])  # 原始像素空间 (60000,784)

# =========================

if XC.shape[0] != Z_train.shape[1]:
    XC = XC.T
if S.shape[1] != X_train.shape[0]:
    S = S.T  # (60000, 50)

# =========================

Z_pca = pca.transform(X_train)
X_pca_rec = pca.inverse_transform(Z_pca)

# =========================
Z_rec = (XC @ S).T  # (60000, 32)
X_aa_rec = pca.inverse_transform(Z_rec)

# =========================
mse_pca = ((X_train - X_pca_rec) ** 2).mean(axis=1)
mse_aa  = ((X_train - X_aa_rec)  ** 2).mean(axis=1)

# =========================
results = {
    int(c): {"PCA": mse_pca[y_train == c].mean(), "AA": mse_aa[y_train == c].mean()}
    for c in np.unique(y_train)
}
results["ALL"] = {"PCA": mse_pca.mean(), "AA": mse_aa.mean()}

# =========================
print("\n==== PCA vs AA Reconstruction MSE (in pixel space) ====")
for c in sorted([k for k in results.keys() if isinstance(k, (int, np.integer))]):
    print(f"Class {c}: PCA={results[c]['PCA']:.6f} | AA={results[c]['AA']:.6f}")
print(f"ALL: PCA={results['ALL']['PCA']:.6f} | AA={results['ALL']['AA']:.6f}")
print("========================================================")
# Out:
# ==== PCA vs AA Reconstruction MSE (in pixel space) ====
# Class 0: PCA=0.017908 | AA=0.031546
# Class 1: PCA=0.007942 | AA=0.012228
# Class 2: PCA=0.022924 | AA=0.040037
# Class 3: PCA=0.018565 | AA=0.036220
# Class 4: PCA=0.017127 | AA=0.033158
# Class 5: PCA=0.019663 | AA=0.036990
# Class 6: PCA=0.018383 | AA=0.032745
# Class 7: PCA=0.015402 | AA=0.027077
# Class 8: PCA=0.020742 | AA=0.036432
# Class 9: PCA=0.015340 | AA=0.029051
# ALL: PCA=0.017243 | AA=0.031226
# ========================================================

# %%
import numpy as np
import matplotlib.pyplot as plt
import joblib
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import os

def visualize_linear_AA(save_dir="./results/mnist_linear_AA"):
    # =========================
    # Load models and latent data
    # =========================
    pca = joblib.load(f"{save_dir}/pca_model.pkl")
    A_global = np.load(f"{save_dir}/A_global.npy")
    XC = np.load(f"{save_dir}/XC_latent.npy")
    S = np.load(f"{save_dir}/S_coeff.npy")

    # Load MNIST data
    transform = transforms.Compose([transforms.ToTensor()])
    ds_train = datasets.MNIST("./data", train=True, transform=transform, download=True)
    X_train = np.array([img.numpy().flatten() for img, _ in ds_train])
    y_train = np.array([label for _, label in ds_train])

    # Select one sample per digit
    selected_idxs = [np.where(y_train == i)[0][0] for i in range(10)]
    X_selected = X_train[selected_idxs]
    y_selected = y_train[selected_idxs]

    # Shape adjustment
    if S.shape[0] != 50:
        S = S.T
    if XC.shape[1] != 50:
        XC = XC.T

    # PCA reconstruction
    Z_selected = pca.transform(X_selected)
    X_pca_rec = pca.inverse_transform(Z_selected)

    # PCA + AA reconstruction
    S_selected = S[:, selected_idxs]
    Z_rec_AA = (XC @ S_selected).T
    X_AA_rec = pca.inverse_transform(Z_rec_AA)

    # =========================
    # Plotting (match AE/VAE style)
    # =========================
    fig, axes = plt.subplots(3, 10, figsize=(20, 6))  # SAME as AE/VAE version

    for col, i in enumerate(range(10)):
        orig = X_selected[i].reshape(28, 28)
        pca_rec = X_pca_rec[i].reshape(28, 28)
        aa_rec = X_AA_rec[i].reshape(28, 28)

        mse_pca = np.mean((pca_rec - orig) ** 2)
        mse_aa = np.mean((aa_rec - orig) ** 2)

        # Row 1: Original
        axes[0, col].imshow(orig, cmap="gray")
        axes[0, col].set_title(f"Label: {y_selected[i]}", fontsize=10)
        axes[0, col].axis("off")

        # Row 2: PCA reconstruction
        axes[1, col].imshow(pca_rec, cmap="gray")
        axes[1, col].set_title(f"PCA\nMSE: {mse_pca:.4f}", fontsize=8, color="blue")
        axes[1, col].axis("off")

        # Row 3: PCA+AA reconstruction
        axes[2, col].imshow(aa_rec, cmap="gray")
        axes[2, col].set_title(f"PCA+AA\nMSE: {mse_aa:.4f}", fontsize=8, color="red")
        axes[2, col].axis("off")

    # fig.suptitle("Digits 0–9: Original / PCA Reconstruction / PCA→AA Reconstruction", fontsize=14)
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.show()

# ------------------------
visualize_linear_AA("./results/mnist_linear_AA")

# %% [markdown]
# # AE-AA
#
# https://journals.plos.org/ploscompbiol/article?id=10.1371/journal.pcbi.1010025
#
# Non-linear archetypal analysis of single-cell RNA-seq data by deep autoencoders

# %%
import torch
import torch.nn.functional as F
from torch.utils.data import DataLoader, Subset
from torchvision import datasets, transforms
import random
import numpy as np
from sklearn.cluster import KMeans
import os 
import json 
import pickle 
import sys

# ----------------------------
# Config / 配置
# ----------------------------
SEED = 42
def set_seed(s=SEED):
    random.seed(s)
    np.random.seed(s)
    torch.manual_seed(s)
    torch.cuda.manual_seed(s)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
set_seed()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"[Init] Using device: {device}")

batch_size = 500
max_epochs = 50
latent_dim = 32
lr = 5e-3
train_subset_size = 20000
warmup_epochs = 5
semantic_epochs = 10

nu_x_tilde = 300
gamma = 1
beta = 0.01
cos_sim_weight = 1.0

num_archetypes_per_class = 5
num_classes = 10
total_archetypes = num_archetypes_per_class * num_classes

EXP_DIR = "./results/mnist_ae_seed42_aa5"
os.makedirs(EXP_DIR, exist_ok=True)

# ----------------------------
# Data 
transform = transforms.Compose([transforms.ToTensor()])
full_train_set = datasets.MNIST("./data", train=True, download=True, transform=transform)
test_set = datasets.MNIST("./data", train=False, download=True, transform=transform)

img_channels, img_size = 1, 28

train_loader_full = DataLoader(full_train_set, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False)

def prepare_class_full_data(full_train_set, device):
    class_full_imgs = {}
    for img, label in full_train_set:
        label = int(label)
        if label not in class_full_imgs:
            class_full_imgs[label] = []
        class_full_imgs[label].append(img.unsqueeze(0))
    for label in class_full_imgs:
        class_full_imgs[label] = torch.cat(class_full_imgs[label]).to(device)
    return class_full_imgs

class_full_imgs = prepare_class_full_data(full_train_set, device)

# ----------------------------
# Model 
class AEWithAA(torch.nn.Module):
    def __init__(self, latent_dim=32, img_channels=1, img_size=28, num_classes=10):
        super().__init__()
        self.encoder = torch.nn.Sequential(
            torch.nn.Conv2d(1, 32, 3, stride=2, padding=1), torch.nn.ReLU(),
            torch.nn.Conv2d(32, 64, 3, stride=2, padding=1), torch.nn.ReLU(),
            torch.nn.Flatten(),
            torch.nn.Linear(7 * 7 * 64, 512), torch.nn.ReLU(),
            torch.nn.Linear(512, latent_dim)
        )
        self.decoder = torch.nn.Sequential(
            torch.nn.Linear(latent_dim, 512), torch.nn.ReLU(),
            torch.nn.Linear(512, 7 * 7 * 64),
            torch.nn.Unflatten(1, (64, 7, 7)),
            torch.nn.ConvTranspose2d(64, 32, 4, 2, 1), torch.nn.ReLU(),
            torch.nn.ConvTranspose2d(32, 1, 4, 2, 1), torch.nn.Sigmoid()
        )
        self.arch_logits = torch.nn.ParameterDict()
        self.class_full_mu = {}
        self.fc_sample_to_aa = torch.nn.Linear(latent_dim, total_archetypes)

    def encode(self, x):
        h = self.encoder(x)
        mu = h / (h.norm(dim=1, keepdim=True) + 1e-8)
        return mu

    def decode(self, z):
        return self.decoder(z)

    def init_class_archetypes(self, class_full_imgs, device):
        print("[Init] Initializing archetypes for all classes...")
        self.eval()
        for label, imgs in class_full_imgs.items():
            mu = self.encode(imgs)
            self.class_full_mu[label] = mu.detach()
            mu_np = mu.detach().cpu().numpy()
            km = KMeans(n_clusters=num_archetypes_per_class, random_state=SEED, n_init=10).fit(mu_np)
            centers = torch.tensor(km.cluster_centers_, device=device, dtype=mu.dtype)
            dists = torch.cdist(centers, mu)
            idx = dists.topk(k=20, largest=False).indices
            logits = torch.zeros(num_archetypes_per_class, mu.size(0), device=device)
            for i in range(num_archetypes_per_class):
                logits[i, idx[i]] = 5.0
            self.arch_logits[str(label)] = torch.nn.Parameter(logits, requires_grad=True)
        print("[Init] Archetypes (logits) initialized successfully!")
        self.train()

    def get_all_archetypes(self):
        all_arch = []
        for label in sorted(self.arch_logits.keys()):
            W = F.softmax(self.arch_logits[label], dim=1)
            X_mu_full = self.class_full_mu[int(label)]
            all_arch.append(W @ X_mu_full)
        return torch.cat(all_arch, dim=0)

    def forward(self, x):
        mu = self.encode(x)
        z = mu
        sample_to_aa_weights = F.softmax(self.fc_sample_to_aa(mu), dim=1)
        x_hat = self.decode(z)
        return x_hat, z, mu, torch.zeros(1).to(device), torch.zeros(1).to(device), sample_to_aa_weights

# ----------------------------
# Loss functions
def kl_loss(mu, logvar): return torch.tensor(0.0).to(mu.device)
def recon_loss(x_hat, x): return F.mse_loss(x_hat, x, reduction='mean')

def cos_similarity_loss(mu_batch, all_archetypes, weights_batch):
    recon_sample = torch.matmul(weights_batch, all_archetypes)
    cos_sim = F.cosine_similarity(recon_sample, mu_batch, dim=1).mean()
    return (1 - cos_sim)

def total_aa_loss(model, mu, y):
    all_archetypes = model.get_all_archetypes()
    weights_batch = F.softmax(model.fc_sample_to_aa(mu), dim=1)
    recon_sample = torch.matmul(weights_batch, all_archetypes)
    loss_sample = F.mse_loss(recon_sample, mu)
    loss_cos = cos_similarity_loss(mu, all_archetypes, weights_batch)
    total_loss = loss_sample + cos_sim_weight * loss_cos
    return total_loss, loss_sample.item(), loss_cos.item()

# ----------------------------
# Training
# ----------------------------
def compute_epoch_losses(model, loader, device, is_train, optimizer=None, epoch=0):
    model.train() if is_train else model.eval()
    total_I_tx = total_I_ty = total_recon = total_AA = total_total = 0.0
    total_samples = 0
    use_aa_beta = (epoch >= semantic_epochs)
    epoch_total_loss_list = []
    with torch.set_grad_enabled(is_train):
        for batch_idx, (x, y) in enumerate(loader):
            x, y = x.to(device), y.to(device)
            x_hat, z, mu, _, _, _ = model(x)
            I_tx = kl_loss(mu, None)
            recon = recon_loss(x_hat, x)
            I_ty_display = 0.0
            if use_aa_beta:
                L_at, avg_Ls, avg_La = total_aa_loss(model, mu, y)
            else:
                L_at, avg_Ls, avg_La = torch.tensor(0.0).to(device), 0.0, 0.0
            total_loss = I_tx + nu_x_tilde * recon
            if use_aa_beta:
                total_loss += gamma * L_at
            if is_train:
                optimizer.zero_grad()
                total_loss.backward()
                optimizer.step()
            bs = x.size(0)
            total_I_tx += I_tx.item() * bs
            total_recon += recon.item() * bs
            total_AA += L_at.item() * bs
            total_total += total_loss.item() * bs
            total_samples += bs
            epoch_total_loss_list.append(total_loss.item())
            if (batch_idx + 1) % 10 == 0:
                sys.stdout.write(f"[Train] Batch {batch_idx+1:03d} | Recon: {recon.item():.4f} | Total: {total_loss.item():.4f}\n")
                if use_aa_beta:
                    sys.stdout.write(f"   ↳ AA sample loss: {avg_Ls:.6f} | AA cos loss: {avg_La:.6f}\n")
                sys.stdout.flush()
    avg_total = total_total / total_samples
    return avg_total, epoch_total_loss_list

# ----------------------------
# Main
# ----------------------------
if __name__ == "__main__":
    model = AEWithAA(latent_dim=latent_dim, img_channels=img_channels, img_size=img_size, num_classes=num_classes).to(device)
    optimizer = torch.optim.Adam([{"params": model.parameters(), "lr": lr}])
    epoch_losses = []

    print(f"[Training Start] {max_epochs} epochs total")
    print(f"Results will be saved to: {EXP_DIR}")

    for epoch in range(max_epochs):
        use_aa_beta = (epoch >= semantic_epochs)
        print(f"===================== Epoch {epoch+1}/{max_epochs} =====================")
        if epoch < semantic_epochs:
            print("Mode: Warmup/Reconstruction only")
        else:
            print("Mode: Full (Recon + AA-MSE + AA-Cos)")

        rand_idx = random.sample(range(len(full_train_set)), train_subset_size)
        train_subset = Subset(full_train_set, rand_idx)
        train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)

        if epoch == semantic_epochs:
            model.init_class_archetypes(class_full_imgs, device)
            for p in model.arch_logits.parameters():
                p.requires_grad = True
            optimizer.add_param_group({"params": model.arch_logits.parameters(), "lr": 1e-2})

        avg_total, epoch_total_loss_list = compute_epoch_losses(model, train_loader, device, True, optimizer, epoch)
        epoch_losses.append(avg_total)
        print(f"\n[Summary] Epoch {epoch+1} Train Total Loss: {avg_total:.4f}")
        print("=======================================================================\n")

    # ----------------------------

    loss_path = os.path.join(EXP_DIR, "epoch_total_losses.pkl")
    with open(loss_path, "wb") as f:
        pickle.dump(epoch_losses, f)
    print(f"[Save] Epoch losses saved to: {loss_path}")

    torch.save(model.state_dict(), os.path.join(EXP_DIR, "model_final.pth"))
    torch.save(model, os.path.join(EXP_DIR, "model_full.pth"))
    print(f"[Save] Final model saved to: {EXP_DIR}")

    if hasattr(model, "get_all_archetypes"):
        all_arch = model.get_all_archetypes().cpu().detach().numpy()
        np.save(os.path.join(EXP_DIR, "final_archetypes.npy"), all_arch)
        decoded = model.decode(model.get_all_archetypes().to(device)).cpu().detach().numpy()
        np.save(os.path.join(EXP_DIR, "final_archetypes_decoded.npy"), decoded)
        print(f"[Save] Archetypes & decoded saved to: {EXP_DIR}")

    print("\n[PostProcess] Saving full latent reconstruction results ...")
    full_loader = DataLoader(full_train_set, batch_size=batch_size, shuffle=False)
    model.eval()
    all_mu, all_mu_aa, all_decoded_mu, all_decoded_mu_aa, all_mse = [], [], [], [], []
    with torch.no_grad():
        all_archetypes = model.get_all_archetypes().to(device)
        for x, _ in full_loader:
            x = x.to(device)
            mu = model.encode(x)
            weights = F.softmax(model.fc_sample_to_aa(mu), dim=1)
            mu_aa = weights @ all_archetypes
            decoded_mu = model.decode(mu)
            decoded_mu_aa = model.decode(mu_aa)
            mse = F.mse_loss(decoded_mu_aa, x, reduction="none").mean(dim=[1, 2, 3])
            all_mu.append(mu.cpu())
            all_mu_aa.append(mu_aa.cpu())
            all_decoded_mu.append(decoded_mu.cpu())
            all_decoded_mu_aa.append(decoded_mu_aa.cpu())
            all_mse.append(mse.cpu())

    np.save(os.path.join(EXP_DIR, "latent_mu.npy"), torch.cat(all_mu).numpy())
    np.save(os.path.join(EXP_DIR, "latent_mu_AA.npy"), torch.cat(all_mu_aa).numpy())
    np.save(os.path.join(EXP_DIR, "decoded_mu.npy"), torch.cat(all_decoded_mu).numpy())
    np.save(os.path.join(EXP_DIR, "decoded_mu_AA.npy"), torch.cat(all_decoded_mu_aa).numpy())
    np.save(os.path.join(EXP_DIR, "reconstruction_mse.npy"), torch.cat(all_mse).numpy())

    mean_mse = torch.cat(all_mse).mean().item()
    with open(os.path.join(EXP_DIR, "reconstruction_mse_mean.txt"), "w") as f:
        f.write(f"Average MSE (AA reconstruction): {mean_mse:.6f}\n")
    print(f"[Done] AA reconstruction results saved to: {EXP_DIR}")
    print(f"Average AA reconstruction MSE = {mean_mse:.6f}")
# Out:
# [Init] Using device: cpu
# [Training Start] 50 epochs total
# Results will be saved to: ./results/mnist_ae_seed42_aa5
# ===================== Epoch 1/50 =====================
# Mode: Warmup/Reconstruction only
# [Train] Batch 010 | Recon: 0.0704 | Total: 21.1335
# [Train] Batch 020 | Recon: 0.0686 | Total: 20.5666
# [Train] Batch 030 | Recon: 0.0691 | Total: 20.7310
# [Train] Batch 040 | Recon: 0.0658 | Total: 19.7392
#
# [Summary] Epoch 1 Train Total Loss: 23.9250
# =======================================================================
#
# ===================== Epoch 2/50 =====================
# Mode: Warmup/Reconstruction only
# [Train] Batch 010 | Recon: 0.0600 | Total: 18.0143
# [Train] Batch 020 | Recon: 0.0585 | Total: 17.5403
# [Train] Batch 030 | Recon: 0.0560 | Total: 16.7860
# [Train] Batch 040 | Recon: 0.0550 | Total: 16.5080
#
# [Summary] Epoch 2 Train Total Loss: 17.5061
# =======================================================================
#
# ===================== Epoch 3/50 =====================
# Mode: Warmup/Reconstruction only
# [Train] Batch 010 | Recon: 0.0501 | Total: 15.0201
# [Train] Batch 020 | Recon: 0.0454 | Total: 13.6086
# [Train] Batch 030 | Recon: 0.0399 | Total: 11.9765
# [Train] Batch 040 | Recon: 0.0390 | Total: 11.7044
#
# [Summary] Epoch 3 Train Total Loss: 13.6405
# =======================================================================
#
# ===================== Epoch 4/50 =====================
# Mode: Warmup/Reconstruction only
# [Train] Batch 010 | Recon: 0.0362 | Total: 10.8727
# [Train] Batch 020 | Recon: 0.0343 | Total: 10.2991
# [Train] Batch 030 | Recon: 0.0332 | Total: 9.9666
# [Train] Batch 040 | Recon: 0.0309 | Total: 9.2700
#
# [Summary] Epoch 4 Train Total Loss: 10.2234
# =======================================================================
#
# ===================== Epoch 5/50 =====================
# Mode: Warmup/Reconstruction only
# [Train] Batch 010 | Recon: 0.0285 | Total: 8.5355
# [Train] Batch 020 | Recon: 0.0273 | Total: 8.1909
# [Train] Batch 030 | Recon: 0.0254 | Total: 7.6189
# [Train] Batch 040 | Recon: 0.0249 | Total: 7.4621
#
# [Summary] Epoch 5 Train Total Loss: 8.1392
# =======================================================================
#
# ===================== Epoch 6/50 =====================
# Mode: Warmup/Reconstruction only
# [Train] Batch 010 | Recon: 0.0242 | Total: 7.2578
# [Train] Batch 020 | Recon: 0.0219 | Total: 6.5738
# [Train] Batch 030 | Recon: 0.0219 | Total: 6.5613
# [Train] Batch 040 | Recon: 0.0203 | Total: 6.1046
#
# [Summary] Epoch 6 Train Total Loss: 6.7177
# =======================================================================
#
# ===================== Epoch 7/50 =====================
# Mode: Warmup/Reconstruction only
# [Train] Batch 010 | Recon: 0.0189 | Total: 5.6765
# [Train] Batch 020 | Recon: 0.0186 | Total: 5.5678
# [Train] Batch 030 | Recon: 0.0179 | Total: 5.3779
# [Train] Batch 040 | Recon: 0.0172 | Total: 5.1617
#
# [Summary] Epoch 7 Train Total Loss: 5.6024
# =======================================================================
#
# ===================== Epoch 8/50 =====================
# Mode: Warmup/Reconstruction only
# [Train] Batch 010 | Recon: 0.0165 | Total: 4.9576
# [Train] Batch 020 | Recon: 0.0158 | Total: 4.7451
# [Train] Batch 030 | Recon: 0.0154 | Total: 4.6255
# [Train] Batch 040 | Recon: 0.0158 | Total: 4.7295
#
# [Summary] Epoch 8 Train Total Loss: 4.8265
# =======================================================================
#
# ===================== Epoch 9/50 =====================
# Mode: Warmup/Reconstruction only
# [Train] Batch 010 | Recon: 0.0149 | Total: 4.4811
# [Train] Batch 020 | Recon: 0.0147 | Total: 4.4202
# [Train] Batch 030 | Recon: 0.0144 | Total: 4.3167
# [Train] Batch 040 | Recon: 0.0140 | Total: 4.2018
#
# [Summary] Epoch 9 Train Total Loss: 4.2922
# =======================================================================
#
# ===================== Epoch 10/50 =====================
# Mode: Warmup/Reconstruction only
# [Train] Batch 010 | Recon: 0.0134 | Total: 4.0291
# [Train] Batch 020 | Recon: 0.0132 | Total: 3.9565
# [Train] Batch 030 | Recon: 0.0119 | Total: 3.5805
# [Train] Batch 040 | Recon: 0.0121 | Total: 3.6181
#
# [Summary] Epoch 10 Train Total Loss: 3.8854
# =======================================================================
#
# ===================== Epoch 11/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Init] Initializing archetypes for all classes...
# [Init] Archetypes (logits) initialized successfully!
# [Train] Batch 010 | Recon: 0.0114 | Total: 3.7960
#    ↳ AA sample loss: 0.018596 | AA cos loss: 0.358941
# [Train] Batch 020 | Recon: 0.0117 | Total: 3.7929
#    ↳ AA sample loss: 0.015791 | AA cos loss: 0.278209
# [Train] Batch 030 | Recon: 0.0125 | Total: 3.9849
#    ↳ AA sample loss: 0.014161 | AA cos loss: 0.229443
# [Train] Batch 040 | Recon: 0.0115 | Total: 3.6617
#    ↳ AA sample loss: 0.013455 | AA cos loss: 0.206369
#
# [Summary] Epoch 11 Train Total Loss: 3.9070
# =======================================================================
#
# ===================== Epoch 12/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0109 | Total: 3.4400
#    ↳ AA sample loss: 0.012273 | AA cos loss: 0.169572
# [Train] Batch 020 | Recon: 0.0124 | Total: 3.8842
#    ↳ AA sample loss: 0.012021 | AA cos loss: 0.160530
# [Train] Batch 030 | Recon: 0.0109 | Total: 3.4165
#    ↳ AA sample loss: 0.011537 | AA cos loss: 0.144548
# [Train] Batch 040 | Recon: 0.0107 | Total: 3.3460
#    ↳ AA sample loss: 0.010852 | AA cos loss: 0.123916
#
# [Summary] Epoch 12 Train Total Loss: 3.5699
# =======================================================================
#
# ===================== Epoch 13/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0112 | Total: 3.4933
#    ↳ AA sample loss: 0.010651 | AA cos loss: 0.116957
# [Train] Batch 020 | Recon: 0.0103 | Total: 3.2062
#    ↳ AA sample loss: 0.010302 | AA cos loss: 0.105713
# [Train] Batch 030 | Recon: 0.0101 | Total: 3.1239
#    ↳ AA sample loss: 0.009978 | AA cos loss: 0.096993
# [Train] Batch 040 | Recon: 0.0105 | Total: 3.2585
#    ↳ AA sample loss: 0.009794 | AA cos loss: 0.089847
#
# [Summary] Epoch 13 Train Total Loss: 3.2823
# =======================================================================
#
# ===================== Epoch 14/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0101 | Total: 3.1116
#    ↳ AA sample loss: 0.009520 | AA cos loss: 0.083282
# [Train] Batch 020 | Recon: 0.0097 | Total: 2.9866
#    ↳ AA sample loss: 0.009217 | AA cos loss: 0.075082
# [Train] Batch 030 | Recon: 0.0108 | Total: 3.3309
#    ↳ AA sample loss: 0.009056 | AA cos loss: 0.070488
# [Train] Batch 040 | Recon: 0.0103 | Total: 3.1614
#    ↳ AA sample loss: 0.009013 | AA cos loss: 0.069846
#
# [Summary] Epoch 14 Train Total Loss: 3.1046
# =======================================================================
#
# ===================== Epoch 15/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0094 | Total: 2.8804
#    ↳ AA sample loss: 0.008703 | AA cos loss: 0.064074
# [Train] Batch 020 | Recon: 0.0094 | Total: 2.8872
#    ↳ AA sample loss: 0.008627 | AA cos loss: 0.064463
# [Train] Batch 030 | Recon: 0.0095 | Total: 2.9239
#    ↳ AA sample loss: 0.008402 | AA cos loss: 0.058127
# [Train] Batch 040 | Recon: 0.0091 | Total: 2.7994
#    ↳ AA sample loss: 0.008160 | AA cos loss: 0.053848
#
# [Summary] Epoch 15 Train Total Loss: 2.9670
# =======================================================================
#
# ===================== Epoch 16/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0086 | Total: 2.6360
#    ↳ AA sample loss: 0.008065 | AA cos loss: 0.052271
# [Train] Batch 020 | Recon: 0.0090 | Total: 2.7713
#    ↳ AA sample loss: 0.008072 | AA cos loss: 0.052384
# [Train] Batch 030 | Recon: 0.0093 | Total: 2.8625
#    ↳ AA sample loss: 0.008075 | AA cos loss: 0.051620
# [Train] Batch 040 | Recon: 0.0087 | Total: 2.6754
#    ↳ AA sample loss: 0.007939 | AA cos loss: 0.049422
#
# [Summary] Epoch 16 Train Total Loss: 2.7874
# =======================================================================
#
# ===================== Epoch 17/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0092 | Total: 2.8055
#    ↳ AA sample loss: 0.007923 | AA cos loss: 0.051429
# [Train] Batch 020 | Recon: 0.0085 | Total: 2.6085
#    ↳ AA sample loss: 0.007880 | AA cos loss: 0.050675
# [Train] Batch 030 | Recon: 0.0086 | Total: 2.6487
#    ↳ AA sample loss: 0.007798 | AA cos loss: 0.049365
# [Train] Batch 040 | Recon: 0.0088 | Total: 2.6897
#    ↳ AA sample loss: 0.007810 | AA cos loss: 0.048966
#
# [Summary] Epoch 17 Train Total Loss: 2.7388
# =======================================================================
#
# ===================== Epoch 18/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0085 | Total: 2.6128
#    ↳ AA sample loss: 0.007731 | AA cos loss: 0.049190
# [Train] Batch 020 | Recon: 0.0089 | Total: 2.7205
#    ↳ AA sample loss: 0.007727 | AA cos loss: 0.049317
# [Train] Batch 030 | Recon: 0.0087 | Total: 2.6579
#    ↳ AA sample loss: 0.007649 | AA cos loss: 0.048108
# [Train] Batch 040 | Recon: 0.0084 | Total: 2.5692
#    ↳ AA sample loss: 0.007513 | AA cos loss: 0.044457
#
# [Summary] Epoch 18 Train Total Loss: 2.6203
# =======================================================================
#
# ===================== Epoch 19/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0082 | Total: 2.5158
#    ↳ AA sample loss: 0.007490 | AA cos loss: 0.045701
# [Train] Batch 020 | Recon: 0.0083 | Total: 2.5308
#    ↳ AA sample loss: 0.007430 | AA cos loss: 0.043552
# [Train] Batch 030 | Recon: 0.0083 | Total: 2.5333
#    ↳ AA sample loss: 0.007451 | AA cos loss: 0.044086
# [Train] Batch 040 | Recon: 0.0080 | Total: 2.4429
#    ↳ AA sample loss: 0.007336 | AA cos loss: 0.043524
#
# [Summary] Epoch 19 Train Total Loss: 2.5510
# =======================================================================
#
# ===================== Epoch 20/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0081 | Total: 2.4839
#    ↳ AA sample loss: 0.007370 | AA cos loss: 0.043051
# [Train] Batch 020 | Recon: 0.0080 | Total: 2.4621
#    ↳ AA sample loss: 0.007364 | AA cos loss: 0.040906
# [Train] Batch 030 | Recon: 0.0079 | Total: 2.4266
#    ↳ AA sample loss: 0.007312 | AA cos loss: 0.041338
# [Train] Batch 040 | Recon: 0.0076 | Total: 2.3387
#    ↳ AA sample loss: 0.007325 | AA cos loss: 0.041285
#
# [Summary] Epoch 20 Train Total Loss: 2.4544
# =======================================================================
#
# ===================== Epoch 21/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0079 | Total: 2.4200
#    ↳ AA sample loss: 0.007287 | AA cos loss: 0.039469
# [Train] Batch 020 | Recon: 0.0078 | Total: 2.3931
#    ↳ AA sample loss: 0.007256 | AA cos loss: 0.039408
# [Train] Batch 030 | Recon: 0.0076 | Total: 2.3177
#    ↳ AA sample loss: 0.007323 | AA cos loss: 0.040734
# [Train] Batch 040 | Recon: 0.0076 | Total: 2.3311
#    ↳ AA sample loss: 0.007299 | AA cos loss: 0.041683
#
# [Summary] Epoch 21 Train Total Loss: 2.3739
# =======================================================================
#
# ===================== Epoch 22/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0079 | Total: 2.4070
#    ↳ AA sample loss: 0.007255 | AA cos loss: 0.039435
# [Train] Batch 020 | Recon: 0.0076 | Total: 2.3395
#    ↳ AA sample loss: 0.007201 | AA cos loss: 0.038986
# [Train] Batch 030 | Recon: 0.0079 | Total: 2.4163
#    ↳ AA sample loss: 0.007316 | AA cos loss: 0.039699
# [Train] Batch 040 | Recon: 0.0077 | Total: 2.3620
#    ↳ AA sample loss: 0.007346 | AA cos loss: 0.040050
#
# [Summary] Epoch 22 Train Total Loss: 2.3533
# =======================================================================
#
# ===================== Epoch 23/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0072 | Total: 2.2079
#    ↳ AA sample loss: 0.007330 | AA cos loss: 0.039947
# [Train] Batch 020 | Recon: 0.0073 | Total: 2.2330
#    ↳ AA sample loss: 0.007148 | AA cos loss: 0.037018
# [Train] Batch 030 | Recon: 0.0075 | Total: 2.3086
#    ↳ AA sample loss: 0.007155 | AA cos loss: 0.037656
# [Train] Batch 040 | Recon: 0.0069 | Total: 2.1127
#    ↳ AA sample loss: 0.007143 | AA cos loss: 0.036731
#
# [Summary] Epoch 23 Train Total Loss: 2.2542
# =======================================================================
#
# ===================== Epoch 24/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0067 | Total: 2.0448
#    ↳ AA sample loss: 0.007146 | AA cos loss: 0.035690
# [Train] Batch 020 | Recon: 0.0066 | Total: 2.0170
#    ↳ AA sample loss: 0.007107 | AA cos loss: 0.035865
# [Train] Batch 030 | Recon: 0.0071 | Total: 2.1821
#    ↳ AA sample loss: 0.007166 | AA cos loss: 0.036739
# [Train] Batch 040 | Recon: 0.0069 | Total: 2.1053
#    ↳ AA sample loss: 0.007064 | AA cos loss: 0.035390
#
# [Summary] Epoch 24 Train Total Loss: 2.1957
# =======================================================================
#
# ===================== Epoch 25/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0067 | Total: 2.0492
#    ↳ AA sample loss: 0.007159 | AA cos loss: 0.036307
# [Train] Batch 020 | Recon: 0.0069 | Total: 2.1176
#    ↳ AA sample loss: 0.007178 | AA cos loss: 0.036231
# [Train] Batch 030 | Recon: 0.0069 | Total: 2.1140
#    ↳ AA sample loss: 0.007209 | AA cos loss: 0.035146
# [Train] Batch 040 | Recon: 0.0066 | Total: 2.0315
#    ↳ AA sample loss: 0.007135 | AA cos loss: 0.034546
#
# [Summary] Epoch 25 Train Total Loss: 2.1411
# =======================================================================
#
# ===================== Epoch 26/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0069 | Total: 2.1175
#    ↳ AA sample loss: 0.007123 | AA cos loss: 0.034568
# [Train] Batch 020 | Recon: 0.0069 | Total: 2.1221
#    ↳ AA sample loss: 0.007166 | AA cos loss: 0.033547
# [Train] Batch 030 | Recon: 0.0069 | Total: 2.0960
#    ↳ AA sample loss: 0.007094 | AA cos loss: 0.033845
# [Train] Batch 040 | Recon: 0.0069 | Total: 2.1240
#    ↳ AA sample loss: 0.007194 | AA cos loss: 0.034017
#
# [Summary] Epoch 26 Train Total Loss: 2.1084
# =======================================================================
#
# ===================== Epoch 27/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0068 | Total: 2.0807
#    ↳ AA sample loss: 0.007306 | AA cos loss: 0.035558
# [Train] Batch 020 | Recon: 0.0064 | Total: 1.9615
#    ↳ AA sample loss: 0.007157 | AA cos loss: 0.033800
# [Train] Batch 030 | Recon: 0.0066 | Total: 2.0180
#    ↳ AA sample loss: 0.007074 | AA cos loss: 0.033951
# [Train] Batch 040 | Recon: 0.0066 | Total: 2.0281
#    ↳ AA sample loss: 0.007068 | AA cos loss: 0.032600
#
# [Summary] Epoch 27 Train Total Loss: 2.0528
# =======================================================================
#
# ===================== Epoch 28/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0068 | Total: 2.0833
#    ↳ AA sample loss: 0.007134 | AA cos loss: 0.033381
# [Train] Batch 020 | Recon: 0.0064 | Total: 1.9491
#    ↳ AA sample loss: 0.007110 | AA cos loss: 0.032496
# [Train] Batch 030 | Recon: 0.0067 | Total: 2.0493
#    ↳ AA sample loss: 0.007209 | AA cos loss: 0.033793
# [Train] Batch 040 | Recon: 0.0068 | Total: 2.0759
#    ↳ AA sample loss: 0.007265 | AA cos loss: 0.032750
#
# [Summary] Epoch 28 Train Total Loss: 2.0203
# =======================================================================
#
# ===================== Epoch 29/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0067 | Total: 2.0512
#    ↳ AA sample loss: 0.007218 | AA cos loss: 0.033210
# [Train] Batch 020 | Recon: 0.0064 | Total: 1.9464
#    ↳ AA sample loss: 0.007149 | AA cos loss: 0.030664
# [Train] Batch 030 | Recon: 0.0067 | Total: 2.0382
#    ↳ AA sample loss: 0.007163 | AA cos loss: 0.032027
# [Train] Batch 040 | Recon: 0.0067 | Total: 2.0424
#    ↳ AA sample loss: 0.007100 | AA cos loss: 0.032617
#
# [Summary] Epoch 29 Train Total Loss: 2.0057
# =======================================================================
#
# ===================== Epoch 30/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0063 | Total: 1.9421
#    ↳ AA sample loss: 0.007162 | AA cos loss: 0.032953
# [Train] Batch 020 | Recon: 0.0065 | Total: 1.9780
#    ↳ AA sample loss: 0.007151 | AA cos loss: 0.031873
# [Train] Batch 030 | Recon: 0.0067 | Total: 2.0368
#    ↳ AA sample loss: 0.007179 | AA cos loss: 0.031225
# [Train] Batch 040 | Recon: 0.0062 | Total: 1.8968
#    ↳ AA sample loss: 0.007147 | AA cos loss: 0.031669
#
# [Summary] Epoch 30 Train Total Loss: 1.9507
# =======================================================================
#
# ===================== Epoch 31/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0065 | Total: 2.0030
#    ↳ AA sample loss: 0.007162 | AA cos loss: 0.031400
# [Train] Batch 020 | Recon: 0.0060 | Total: 1.8276
#    ↳ AA sample loss: 0.007070 | AA cos loss: 0.030416
# [Train] Batch 030 | Recon: 0.0063 | Total: 1.9211
#    ↳ AA sample loss: 0.007151 | AA cos loss: 0.031456
# [Train] Batch 040 | Recon: 0.0065 | Total: 1.9946
#    ↳ AA sample loss: 0.007017 | AA cos loss: 0.030961
#
# [Summary] Epoch 31 Train Total Loss: 1.9426
# =======================================================================
#
# ===================== Epoch 32/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0061 | Total: 1.8810
#    ↳ AA sample loss: 0.007085 | AA cos loss: 0.030762
# [Train] Batch 020 | Recon: 0.0064 | Total: 1.9635
#    ↳ AA sample loss: 0.007143 | AA cos loss: 0.030987
# [Train] Batch 030 | Recon: 0.0065 | Total: 1.9755
#    ↳ AA sample loss: 0.007182 | AA cos loss: 0.031488
# [Train] Batch 040 | Recon: 0.0063 | Total: 1.9282
#    ↳ AA sample loss: 0.007107 | AA cos loss: 0.030927
#
# [Summary] Epoch 32 Train Total Loss: 1.9087
# =======================================================================
#
# ===================== Epoch 33/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0062 | Total: 1.8829
#    ↳ AA sample loss: 0.007140 | AA cos loss: 0.029888
# [Train] Batch 020 | Recon: 0.0060 | Total: 1.8242
#    ↳ AA sample loss: 0.007047 | AA cos loss: 0.030075
# [Train] Batch 030 | Recon: 0.0057 | Total: 1.7489
#    ↳ AA sample loss: 0.007170 | AA cos loss: 0.030464
# [Train] Batch 040 | Recon: 0.0057 | Total: 1.7594
#    ↳ AA sample loss: 0.007070 | AA cos loss: 0.030126
#
# [Summary] Epoch 33 Train Total Loss: 1.8673
# =======================================================================
#
# ===================== Epoch 34/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0062 | Total: 1.8857
#    ↳ AA sample loss: 0.007052 | AA cos loss: 0.028089
# [Train] Batch 020 | Recon: 0.0059 | Total: 1.8070
#    ↳ AA sample loss: 0.007057 | AA cos loss: 0.029493
# [Train] Batch 030 | Recon: 0.0062 | Total: 1.9076
#    ↳ AA sample loss: 0.007174 | AA cos loss: 0.030861
# [Train] Batch 040 | Recon: 0.0060 | Total: 1.8320
#    ↳ AA sample loss: 0.007116 | AA cos loss: 0.029859
#
# [Summary] Epoch 34 Train Total Loss: 1.8652
# =======================================================================
#
# ===================== Epoch 35/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0061 | Total: 1.8621
#    ↳ AA sample loss: 0.007070 | AA cos loss: 0.029823
# [Train] Batch 020 | Recon: 0.0061 | Total: 1.8672
#    ↳ AA sample loss: 0.007086 | AA cos loss: 0.029544
# [Train] Batch 030 | Recon: 0.0058 | Total: 1.7620
#    ↳ AA sample loss: 0.007082 | AA cos loss: 0.028404
# [Train] Batch 040 | Recon: 0.0057 | Total: 1.7549
#    ↳ AA sample loss: 0.007003 | AA cos loss: 0.027872
#
# [Summary] Epoch 35 Train Total Loss: 1.8168
# =======================================================================
#
# ===================== Epoch 36/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0059 | Total: 1.8018
#    ↳ AA sample loss: 0.007121 | AA cos loss: 0.029216
# [Train] Batch 020 | Recon: 0.0059 | Total: 1.8158
#    ↳ AA sample loss: 0.007040 | AA cos loss: 0.028519
# [Train] Batch 030 | Recon: 0.0056 | Total: 1.7218
#    ↳ AA sample loss: 0.007059 | AA cos loss: 0.028292
# [Train] Batch 040 | Recon: 0.0058 | Total: 1.7785
#    ↳ AA sample loss: 0.007198 | AA cos loss: 0.028501
#
# [Summary] Epoch 36 Train Total Loss: 1.8067
# =======================================================================
#
# ===================== Epoch 37/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0056 | Total: 1.7293
#    ↳ AA sample loss: 0.007058 | AA cos loss: 0.028479
# [Train] Batch 020 | Recon: 0.0057 | Total: 1.7455
#    ↳ AA sample loss: 0.007096 | AA cos loss: 0.029355
# [Train] Batch 030 | Recon: 0.0056 | Total: 1.7070
#    ↳ AA sample loss: 0.007128 | AA cos loss: 0.028747
# [Train] Batch 040 | Recon: 0.0059 | Total: 1.7931
#    ↳ AA sample loss: 0.007026 | AA cos loss: 0.027901
#
# [Summary] Epoch 37 Train Total Loss: 1.7639
# =======================================================================
#
# ===================== Epoch 38/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0056 | Total: 1.7154
#    ↳ AA sample loss: 0.007072 | AA cos loss: 0.027886
# [Train] Batch 020 | Recon: 0.0055 | Total: 1.6901
#    ↳ AA sample loss: 0.007028 | AA cos loss: 0.026729
# [Train] Batch 030 | Recon: 0.0059 | Total: 1.8088
#    ↳ AA sample loss: 0.007021 | AA cos loss: 0.028292
# [Train] Batch 040 | Recon: 0.0059 | Total: 1.8134
#    ↳ AA sample loss: 0.007131 | AA cos loss: 0.028657
#
# [Summary] Epoch 38 Train Total Loss: 1.7660
# =======================================================================
#
# ===================== Epoch 39/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0062 | Total: 1.8920
#    ↳ AA sample loss: 0.007179 | AA cos loss: 0.029514
# [Train] Batch 020 | Recon: 0.0061 | Total: 1.8534
#    ↳ AA sample loss: 0.007092 | AA cos loss: 0.027626
# [Train] Batch 030 | Recon: 0.0057 | Total: 1.7375
#    ↳ AA sample loss: 0.007105 | AA cos loss: 0.029016
# [Train] Batch 040 | Recon: 0.0057 | Total: 1.7379
#    ↳ AA sample loss: 0.007128 | AA cos loss: 0.028785
#
# [Summary] Epoch 39 Train Total Loss: 1.7551
# =======================================================================
#
# ===================== Epoch 40/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0058 | Total: 1.7694
#    ↳ AA sample loss: 0.007178 | AA cos loss: 0.028232
# [Train] Batch 020 | Recon: 0.0055 | Total: 1.6717
#    ↳ AA sample loss: 0.007057 | AA cos loss: 0.027220
# [Train] Batch 030 | Recon: 0.0057 | Total: 1.7371
#    ↳ AA sample loss: 0.007083 | AA cos loss: 0.027748
# [Train] Batch 040 | Recon: 0.0057 | Total: 1.7518
#    ↳ AA sample loss: 0.007082 | AA cos loss: 0.027420
#
# [Summary] Epoch 40 Train Total Loss: 1.7226
# =======================================================================
#
# ===================== Epoch 41/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0056 | Total: 1.7031
#    ↳ AA sample loss: 0.007009 | AA cos loss: 0.026603
# [Train] Batch 020 | Recon: 0.0057 | Total: 1.7500
#    ↳ AA sample loss: 0.007038 | AA cos loss: 0.027115
# [Train] Batch 030 | Recon: 0.0058 | Total: 1.7620
#    ↳ AA sample loss: 0.007089 | AA cos loss: 0.027853
# [Train] Batch 040 | Recon: 0.0057 | Total: 1.7363
#    ↳ AA sample loss: 0.007153 | AA cos loss: 0.028422
#
# [Summary] Epoch 41 Train Total Loss: 1.7066
# =======================================================================
#
# ===================== Epoch 42/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0052 | Total: 1.6093
#    ↳ AA sample loss: 0.007075 | AA cos loss: 0.027593
# [Train] Batch 020 | Recon: 0.0055 | Total: 1.6993
#    ↳ AA sample loss: 0.007065 | AA cos loss: 0.027665
# [Train] Batch 030 | Recon: 0.0053 | Total: 1.6234
#    ↳ AA sample loss: 0.007141 | AA cos loss: 0.027930
# [Train] Batch 040 | Recon: 0.0055 | Total: 1.6935
#    ↳ AA sample loss: 0.007052 | AA cos loss: 0.027676
#
# [Summary] Epoch 42 Train Total Loss: 1.6688
# =======================================================================
#
# ===================== Epoch 43/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0052 | Total: 1.5829
#    ↳ AA sample loss: 0.007123 | AA cos loss: 0.027980
# [Train] Batch 020 | Recon: 0.0057 | Total: 1.7495
#    ↳ AA sample loss: 0.007127 | AA cos loss: 0.027198
# [Train] Batch 030 | Recon: 0.0054 | Total: 1.6540
#    ↳ AA sample loss: 0.007025 | AA cos loss: 0.026218
# [Train] Batch 040 | Recon: 0.0052 | Total: 1.5845
#    ↳ AA sample loss: 0.007029 | AA cos loss: 0.026128
#
# [Summary] Epoch 43 Train Total Loss: 1.6503
# =======================================================================
#
# ===================== Epoch 44/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0052 | Total: 1.5799
#    ↳ AA sample loss: 0.007087 | AA cos loss: 0.026597
# [Train] Batch 020 | Recon: 0.0052 | Total: 1.5998
#    ↳ AA sample loss: 0.007118 | AA cos loss: 0.026248
# [Train] Batch 030 | Recon: 0.0051 | Total: 1.5727
#    ↳ AA sample loss: 0.007124 | AA cos loss: 0.025750
# [Train] Batch 040 | Recon: 0.0050 | Total: 1.5385
#    ↳ AA sample loss: 0.007146 | AA cos loss: 0.025595
#
# [Summary] Epoch 44 Train Total Loss: 1.6341
# =======================================================================
#
# ===================== Epoch 45/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0053 | Total: 1.6109
#    ↳ AA sample loss: 0.007094 | AA cos loss: 0.026108
# [Train] Batch 020 | Recon: 0.0053 | Total: 1.6174
#    ↳ AA sample loss: 0.007119 | AA cos loss: 0.026401
# [Train] Batch 030 | Recon: 0.0050 | Total: 1.5467
#    ↳ AA sample loss: 0.007102 | AA cos loss: 0.026532
# [Train] Batch 040 | Recon: 0.0050 | Total: 1.5339
#    ↳ AA sample loss: 0.007093 | AA cos loss: 0.025996
#
# [Summary] Epoch 45 Train Total Loss: 1.6220
# =======================================================================
#
# ===================== Epoch 46/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0052 | Total: 1.5834
#    ↳ AA sample loss: 0.007093 | AA cos loss: 0.026569
# [Train] Batch 020 | Recon: 0.0050 | Total: 1.5189
#    ↳ AA sample loss: 0.007061 | AA cos loss: 0.026262
# [Train] Batch 030 | Recon: 0.0055 | Total: 1.6908
#    ↳ AA sample loss: 0.007168 | AA cos loss: 0.026456
# [Train] Batch 040 | Recon: 0.0054 | Total: 1.6444
#    ↳ AA sample loss: 0.007097 | AA cos loss: 0.026148
#
# [Summary] Epoch 46 Train Total Loss: 1.6080
# =======================================================================
#
# ===================== Epoch 47/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0053 | Total: 1.6089
#    ↳ AA sample loss: 0.007053 | AA cos loss: 0.025285
# [Train] Batch 020 | Recon: 0.0056 | Total: 1.7104
#    ↳ AA sample loss: 0.007101 | AA cos loss: 0.026341
# [Train] Batch 030 | Recon: 0.0053 | Total: 1.6231
#    ↳ AA sample loss: 0.007051 | AA cos loss: 0.026970
# [Train] Batch 040 | Recon: 0.0050 | Total: 1.5368
#    ↳ AA sample loss: 0.007124 | AA cos loss: 0.025961
#
# [Summary] Epoch 47 Train Total Loss: 1.5964
# =======================================================================
#
# ===================== Epoch 48/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0051 | Total: 1.5580
#    ↳ AA sample loss: 0.007075 | AA cos loss: 0.025551
# [Train] Batch 020 | Recon: 0.0048 | Total: 1.4674
#    ↳ AA sample loss: 0.006981 | AA cos loss: 0.025275
# [Train] Batch 030 | Recon: 0.0051 | Total: 1.5477
#    ↳ AA sample loss: 0.007076 | AA cos loss: 0.025128
# [Train] Batch 040 | Recon: 0.0051 | Total: 1.5656
#    ↳ AA sample loss: 0.007048 | AA cos loss: 0.025181
#
# [Summary] Epoch 48 Train Total Loss: 1.5875
# =======================================================================
#
# ===================== Epoch 49/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0053 | Total: 1.6089
#    ↳ AA sample loss: 0.007108 | AA cos loss: 0.025774
# [Train] Batch 020 | Recon: 0.0048 | Total: 1.4817
#    ↳ AA sample loss: 0.007074 | AA cos loss: 0.025555
# [Train] Batch 030 | Recon: 0.0046 | Total: 1.4251
#    ↳ AA sample loss: 0.007017 | AA cos loss: 0.024569
# [Train] Batch 040 | Recon: 0.0052 | Total: 1.6065
#    ↳ AA sample loss: 0.007114 | AA cos loss: 0.026433
#
# [Summary] Epoch 49 Train Total Loss: 1.5424
# =======================================================================
#
# ===================== Epoch 50/50 =====================
# Mode: Full (Recon + AA-MSE + AA-Cos)
# [Train] Batch 010 | Recon: 0.0052 | Total: 1.6064
#    ↳ AA sample loss: 0.007195 | AA cos loss: 0.026541
# [Train] Batch 020 | Recon: 0.0050 | Total: 1.5314
#    ↳ AA sample loss: 0.007009 | AA cos loss: 0.024189
# [Train] Batch 030 | Recon: 0.0050 | Total: 1.5212
#    ↳ AA sample loss: 0.007020 | AA cos loss: 0.024335
# [Train] Batch 040 | Recon: 0.0051 | Total: 1.5545
#    ↳ AA sample loss: 0.007070 | AA cos loss: 0.025148
#
# [Summary] Epoch 50 Train Total Loss: 1.5517
# =======================================================================
#
# [Save] Epoch losses saved to: ./results/mnist_ae_seed42_aa5\epoch_total_losses.pkl
# [Save] Final model saved to: ./results/mnist_ae_seed42_aa5
# [Save] Archetypes & decoded saved to: ./results/mnist_ae_seed42_aa5
#
# [PostProcess] Saving full latent reconstruction results ...
# [Done] AA reconstruction results saved to: ./results/mnist_ae_seed42_aa5
# Average AA reconstruction MSE = 0.035319

# %%
from utils.visualization import plot_decoded_archetypes
plot_decoded_archetypes("results/mnist_ae_seed42_aa5")

# %%
from utils.visualization import visualize_ae_latent_3d
visualize_ae_latent_3d(exp_dir="results/mnist_ae_seed42_aa5", seed=42)
# Out:
# [Step 1/3] Reducing 32D latent space to 3D using t-SNE...
# c:\Users\mingx\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\manifold\_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# [Step 2/3] Computing convex hull for 50 archetypes...
# [Step 3/3] Plotting 3D latent space visualization...

# %%
from utils.evaluation import evaluate_reconstruction_from_saved
evaluate_reconstruction_from_saved(exp_dir="./results/mnist_ae_seed42_aa5", dataset="mnist")
# Out:
# ==== MNIST Reconstruction MSE ====
# Class 0: Direct=0.005994 | AA=0.042077
# Class 1: Direct=0.001716 | AA=0.014763
# Class 2: Direct=0.006598 | AA=0.047699
# Class 3: Direct=0.005669 | AA=0.040563
# Class 4: Direct=0.004900 | AA=0.032844
# Class 5: Direct=0.006164 | AA=0.042279
# Class 6: Direct=0.004999 | AA=0.036532
# Class 7: Direct=0.003770 | AA=0.028719
# Class 8: Direct=0.007444 | AA=0.042964
# Class 9: Direct=0.004345 | AA=0.028400
# Overall: Direct=0.005096 | AA=0.035319
# =============================================

# %%
visualize_digits_grid(exp_dir="./results/mnist_ae_seed42_aa5", dataset="mnist")

# %%
visualize_classwise_aa_usage(exp_dir="./results/mnist_ae_seed42_aa5")
